# %% [markdown]
#  Copyright © Sorbonne University.
#
#  This source code is licensed under the MIT license found in the
#  LICENSE file in the root directory of this source tree.

# %% [markdown]
# # Outlook
#
# In this notebook, you will code a naive actor-critic algorithm in the tabular case. Then you will tune it using grid search and Bayesian optimization, potentially using the [optuna](https://optuna.readthedocs.io/en/stable/) library.
# Finally, you will get the best hyper-parameters obtained with both methods and perform a statistical test to see if there is a statistically significant difference between these methods and with respect to naive hyper-parameter values.
#
# ## Install libraries

# %%
# Installs the necessary Python and system libraries
try:
    from easypip import easyimport, easyinstall, is_notebook
except ModuleNotFoundError as e:
    get_ipython().run_line_magic("pip", "install 'easypip>=1.2.0'")
    from easypip import easyimport, easyinstall, is_notebook

easyinstall("swig")
easyinstall("bbrl>=0.2.2")
easyinstall("bbrl_gymnasium>=0.2.0")
easyinstall("tensorboard")
easyinstall("moviepy")
easyinstall("box2d-kengz")
easyinstall("optuna")
easyinstall("gymnasium")
easyinstall("mazemdp")

import numpy as np
import os
from typing import List

import hydra
import optuna
import yaml
from omegaconf import OmegaConf, DictConfig

# For visualization
os.environ["VIDEO_FPS"] = "5"
if not os.path.isdir("./videos"):
    os.mkdir("./videos")

from IPython.display import Video

# %%
import torch
import torch.nn as nn

# %%
import gymnasium as gym

from bbrl.utils.chrono import Chrono

import matplotlib
# matplotlib.use('Agg')                                
import matplotlib.pyplot as plt

from mazemdp.toolbox import sample_categorical
from mazemdp.mdp import Mdp
from bbrl_gymnasium.envs.maze_mdp import MazeMDPEnv
from gymnasium.wrappers.monitoring.video_recorder import VideoRecorder
from functools import partial

# matplotlib.use("TkAgg")
# Out:
# Matplotlib backend: module://matplotlib_inline.backend_inline

# %% [markdown]
# # Step 1: Coding the naive Actor-critic algorithm
#
# We consider the naive actor-critic algorithm with a categorical policy.
# The algorithm learns a critic with the standard temporal difference mechanism
# using a learning rate $\alpha_{critic}$.
#
# We consider a value-based critic $V(s)$. The extension to an action value function $Q(s,a)$ is straightforward.
#
# To update the critic, the algorithm computes the temporal difference error:
#
# $$\delta_t = r(s_t, a_t) + \gamma V^{(n)}(s_{t+1})-V^{(n)}(s_t).$$
#
# Then it applies it to the critic:
#
# $$V^{(n+1)}(s_t) = V^{(n)}(s_t) + \alpha_{critic} \delta_t.$$
#
# To update the actor, the general idea is the same, using the temporal difference error with another learning rate $\alpha_{actor}$.
#
# However, naively applying the same learning rule would not ensure that the probabilities of all actions in a state sum to 1.
# Besides, when the temporal difference error $\delta_t$ is negative, it may happen that the probability of an action gets negative or null, which raises an issue when applying renormalization.
#
# So, instead of applying the naive rule, we apply the following one:
# $$
# \pi_{temp}(a_t|s_t) =  \begin{cases}
# \pi^{(i)}(a_t|s_t) + \alpha_{actor} \delta_t & \mathrm{if } \pi^{(i)}(a_t|s_t) + \alpha_{actor} \delta_t > 10^{-8}\\
# 10^{-8} & \mathrm{otherwise.} \\
# \end{cases}
# $$
#
# Then we can apply renormalization so that the probabilities of actions still sum to 1, with
# $$
# \forall a, \pi^{(i+1)}(a|s_t) = \frac{\pi_{temp}^{(i+1)}(a|s_t)} {\sum_{a'} \pi_{temp}^{(i+1)}(a'|s_t)}
# $$ with
# $$
# \pi_{temp}^{(i+1)}(a|s_t) =  \begin{cases}
# \pi_{temp}(a|s_t) & \mathrm{if } a = a_t\\
# \pi^{(i)}(a|s_t) & \mathrm{otherwise.} \\
# \end{cases}
# $$
#
# ## Exercise 1
#
# ### 1. Code the naive actor-critic algorithm as specified above.
#
# Some hints:
#
# - a good idea to build this code it to take inspiration from the code of Q-learning, to add an actor (a categorical policy), both learning rates,
# and to take care about the renormalization function.
#
# - for the next steps of this lab, having a function to repeatedly call your actor-critic algorithm and save the learning trajectories and
# norms of the value function is a good idea.

# %%
class Critic:
    def __init__(self, nb_states, alpha=0.5, init_v=0.0):
        self.v = np.zeros(nb_states)
        self.v[:] = init_v
        self.alpha = alpha

    def update(self, x, y, r, gamma):
        delta = r + gamma * self.v[y] - self.v[x]
        self.v[x] += self.alpha * delta

    def get_value_function(self):
        return self.v


class Actor:
    def __init__(self, nb_states, action_space_size, alpha=0.5):
        self.policy = np.ones((nb_states, action_space_size)) / action_space_size
        self.alpha = alpha

    def update(self, x, u, delta):
        if self.policy[x, u] + self.alpha * delta > 1e-8:
            self.policy[x, u] += self.alpha * delta
        else:
            self.policy[x, u] = 1e-8

        self.policy[x] /= np.sum(self.policy[x])  # Normalize the policy

    def get_policy(self):
        return self.policy


def Actor_Critic(mdp, nb_episodes=20, timeout=50, alpha_critic=0.5, alpha_actor=0.5, render=True, init_v=0.0, uniform=True):
    # Initialize Critic and Actor
    critic = Critic(mdp.unwrapped.nb_states, alpha=alpha_critic, init_v=init_v)
    actor = Actor(mdp.unwrapped.nb_states, mdp.action_space.n, alpha=alpha_actor)

    v_list = []
    time_list = []

    mdp.timeout = timeout  # episode length

    if render:
        mdp.init_draw("Actor-Critic")

    for _ in range(nb_episodes):
        # Draw the first state of episode i using a uniform distribution over all the states
        x, _ = mdp.reset(uniform=uniform)
        cpt = 0

        terminated = False
        truncated = False
        while not (terminated or truncated):
            # Show the agent in the maze
            if render:
                mdp.draw_v_pi(critic.get_value_function(), actor.get_policy().argmax(axis=1))

            # Draw an action
            u = np.random.choice(mdp.action_space.n, p=actor.get_policy()[x])

            # Perform a step of the MDP
            y, r, terminated, truncated, _ = mdp.step(u)

            # Update the Critic
            critic.update(x, y, r, mdp.unwrapped.gamma)

            # Update the Actor policy
            actor.update(x, u, r + mdp.unwrapped.gamma * critic.get_value_function()[y] - critic.get_value_function()[x])

            # Update the agent position
            x = y
            cpt += 1

        v_list.append(np.linalg.norm(np.maximum(critic.get_value_function(), 0)))
        time_list.append(cpt)

    if render:
        mdp.current_state = 0
        mdp.draw_v_pi(critic.get_value_function(), actor.get_policy())

    return critic.get_value_function(), v_list, time_list

# %% [markdown]
# ### 2. Provide a plot function
#
# Your plot function should show the evolution through time of number of steps the agent takes to find the reward in the maze.
# If your algorithm works, this number of steps should decrease through time.
#
# Your plot function should also show a mean and a standard deviation (or some more advanced statistics) over a collection of learning runs.

# %%
# To be completed...
def plot_learning_curve(time_list, nb_episodes):
    """
    Plot the learning curve showing the evolution of the number of steps over episodes.

    Parameters:
        time_list (list of lists): A list containing lists of steps for each episode from multiple runs.
        nb_episodes (int): Number of episodes.
    """
    # Convert time_list into a numpy array for easier manipulation
    time_array = np.array(time_list)

    # Calculate the mean and standard deviation
    mean_steps = time_array.mean(axis=0)
    std_steps = time_array.std(axis=0)

    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.plot(mean_steps, label='Mean Steps', color='b')
    plt.fill_between(range(nb_episodes), mean_steps - std_steps, mean_steps + std_steps,
                     color='b', alpha=0.2, label='±1 Std Dev')

    plt.title('Learning Curve: Steps to Reach Reward Over Episodes')
    plt.xlabel('Episodes')
    plt.ylabel('Number of Steps')
    plt.legend()
    plt.grid()
    plt.savefig(
        f"./Learning Curve.png", bbox_inches="tight", dpi=100)
    plt.show()

# assert False, 'Not implemented yet'

# %% [markdown]
# ## Actor-critic hyper-parameters
#
# To represent the hyper-parameters of the experiments performed in this notebook, we suggest using the dictionary below.
# This dictionary can be read using omegaconf.
# Using it is not mandatory.
# You can also change the value of hyper-parameters or environment parameters at will.

# %%
ac_params = {
    "save_curves": False,
    "save_heatmap": True,
    "mdp": {
        "name": "MazeMDP-v0",
        "width": 5,
        "height": 5,
        "ratio": 0.2,
        "render_mode": "rgb_array",
        },
        
    "log_dir": "./tmp",
    "video_dir": "./tmp/videos",

    "nb_episodes": 100,
    "timeout": 200,
    "render": False, # True, # 
    "nb_repeats": 5,

    "alpha_critic": 0.5,
    "alpha_actor": 0.5,
    }

# %% [markdown]
# ### 3. Test your code
#
# Once everything looks OK, save the obtained plot for your lab report

# %%
# To be completed...

env = gym.make(
    id="MazeMDP-v0",
    kwargs={"width": 5, "height": 5, "ratio": 0.2},
    render_mode="rgb_array",
)

env.reset()
# env.unwrapped.init_draw("The maze")
# Out:
# (13, {})

# %%
def run_multiple_episodes(mdp, nb_runs, nb_episodes, timeout, alpha_critic, alpha_actor, render):
    all_time_lists = []
    for run in range(nb_runs):
        _, time_list, _ = Actor_Critic(mdp, nb_episodes, timeout, alpha_critic, alpha_actor, render)
        all_time_lists.append(time_list)
    return all_time_lists

# %%
all_time_lists = run_multiple_episodes(
        mdp = env,
        nb_runs=ac_params['nb_repeats'],
        nb_episodes=ac_params['nb_episodes'],
        timeout=ac_params['timeout'],
        alpha_critic=ac_params['alpha_critic'],
        alpha_actor=ac_params['alpha_actor'],
        render=ac_params['render']
    )

plot_learning_curve(all_time_lists, ac_params['nb_episodes'])

# %% [markdown]
# # Step 2: Tuning hyper-parameters
#
# In this part, you have to optimize two hyper-parameters of the actor-critic algorithm, namely the actor and critic learning rates.
# You have to do so using a simple grid search method and some Bayesian optimization method.
# For the latter, we suggest using the default sampler from [optuna](https://optuna.readthedocs.io/en/stable/).
# Follow the above link to understand how optuna works.
# Note that it also supports grid search and many other hyper-parameters tuning algorithms.
#
# You should make sure that the hyper-parameters tuning algorithms that you compare benefit from the same training budget
# We suggest 400 training runs overall for each method,
# which means 20 values each for the actor and the critic learning rates in the case of grid search.
#
# ## Exercise 2
#
# ### 1. Perform hyper-parameters tuning with two algorithms as suggested above.
#
# ### 2. Provide a "heatmap" of the norm of the value function given the hyper-parameters, after training for each pair of hyper-parameters.
#
# ### 3. Collect the value of the best hyper-parameters found with each algorithm. You will need them for Step 3.
#
# ### 4. Include in your report the heatmaps and the best hyper-parameters found for each method.

# %%
# Hyperparameters for grid search
num_points = 20 # Number of points in the grid for each learning rate
learning_rate_range = np.linspace(0.01, 1.0, num_points)  # Learning rates range for both actor and critic
best_actor_lr = None
best_critic_lr = None
best_value_norm = -np.inf

def grid_search(mdp,num_runs,nb_episodes, timeout, alpha_critic, alpha_actor, render):
  global best_actor_lr,best_critic_lr,best_value_norm

  value_norms = np.zeros((num_points, num_points))

  for i, alpha_actor in enumerate(learning_rate_range):
    for j, alpha_critic in enumerate(learning_rate_range):
      # print(f"Testing Actor LR: {alpha_actor:.2f}, Critic LR: {alpha_critic:.2f}")
      all_time_lists = []

      for run in range(num_runs):
        v, v_list, _ = Actor_Critic(mdp, nb_episodes, timeout, alpha_critic, alpha_actor, render)

        # Store the final norm of the value function
        final_value_norm = np.linalg.norm(v)
        value_norms[i, j] = final_value_norm

        # Update best hyperparameters if needed
        if final_value_norm >= best_value_norm:
          best_value_norm = final_value_norm
          best_actor_lr = alpha_actor
          best_critic_lr = alpha_critic
          # Print the current best value and the corresponding hyperparameters
          print(f"New best value norm: {best_value_norm:.4f} (Actor LR: {best_actor_lr:.2f}, Critic LR: {best_critic_lr:.2f})")

  return value_norms, best_actor_lr, best_critic_lr

# Function to plot heatmap
def plot_heatmap(value_norms, method_name):
    plt.figure(figsize=(10, 8))
    plt.imshow(value_norms, interpolation='nearest')
    plt.colorbar(label='Norm of Value Function')
    plt.xticks(ticks=np.arange(num_points), labels=[f"{lr:.2f}" for lr in learning_rate_range], rotation=45)
    plt.yticks(ticks=np.arange(num_points), labels=[f"{lr:.2f}" for lr in learning_rate_range])
    plt.xlabel('Actor Learning Rate')
    plt.ylabel('Critic Learning Rate')
    plt.title(f"{method_name} Heatmap of Norm of Value Function")
    plt.tight_layout()
    plt.savefig(f"{method_name}_heatmap", bbox_inches="tight", dpi=100)
    plt.show()

# %%
# Main function to execute grid search and save heatmap

# Run grid search
value_norms, best_actor_lr, best_critic_lr = grid_search(
    mdp=env,
    num_runs=ac_params['nb_repeats'],
    nb_episodes=ac_params['nb_episodes'],
    timeout=ac_params['timeout'],
    alpha_critic=ac_params['alpha_critic'],
    alpha_actor=ac_params['alpha_actor'],
    render=ac_params['render']
)

print("Best Actor Learning Rate:", best_actor_lr)
print("Best Critic Learning Rate:", best_critic_lr)
print("Best Norm of Value Function:", best_value_norm)

plot_heatmap(value_norms, 'Grid_Search')
# Out:
# New best value norm: 0.3285 (Actor LR: 0.01, Critic LR: 0.01)
# New best value norm: 1.4838 (Actor LR: 0.01, Critic LR: 0.06)
# New best value norm: 1.6569 (Actor LR: 0.01, Critic LR: 0.06)
# New best value norm: 2.0745 (Actor LR: 0.01, Critic LR: 0.11)
# New best value norm: 2.5039 (Actor LR: 0.01, Critic LR: 0.11)
# New best value norm: 2.7040 (Actor LR: 0.01, Critic LR: 0.17)
# New best value norm: 4.3202 (Actor LR: 0.01, Critic LR: 0.22)
# New best value norm: 4.4277 (Actor LR: 0.01, Critic LR: 0.27)
# New best value norm: 5.8262 (Actor LR: 0.01, Critic LR: 0.27)
# New best value norm: 5.8998 (Actor LR: 0.01, Critic LR: 0.37)
# New best value norm: 6.1151 (Actor LR: 0.01, Critic LR: 0.43)
# New best value norm: 6.5723 (Actor LR: 0.01, Critic LR: 0.43)
# New best value norm: 6.9147 (Actor LR: 0.01, Critic LR: 0.48)
# New best value norm: 7.1057 (Actor LR: 0.01, Critic LR: 0.48)
# New best value norm: 7.9949 (Actor LR: 0.01, Critic LR: 0.53)
# New best value norm: 8.7314 (Actor LR: 0.01, Critic LR: 0.53)
# New best value norm: 9.1546 (Actor LR: 0.01, Critic LR: 0.53)
# New best value norm: 10.1472 (Actor LR: 0.01, Critic LR: 0.69)
# New best value norm: 12.2511 (Actor LR: 0.01, Critic LR: 0.79)
# New best value norm: 15.4350 (Actor LR: 0.06, Critic LR: 0.32)
# New best value norm: 15.7959 (Actor LR: 0.06, Critic LR: 0.32)
# New best value norm: 17.3084 (Actor LR: 0.06, Critic LR: 0.43)
# New best value norm: 17.9105 (Actor LR: 0.06, Critic LR: 0.48)
# New best value norm: 18.3950 (Actor LR: 0.06, Critic LR: 0.74)
# New best value norm: 21.5679 (Actor LR: 0.11, Critic LR: 0.43)
# New best value norm: 21.8607 (Actor LR: 0.11, Critic LR: 0.53)
# New best value norm: 22.0424 (Actor LR: 0.11, Critic LR: 0.64)
# New best value norm: 23.0522 (Actor LR: 0.11, Critic LR: 0.64)
# New best value norm: 23.4185 (Actor LR: 0.11, Critic LR: 0.69)
# New best value norm: 23.7485 (Actor LR: 0.17, Critic LR: 0.53)
# New best value norm: 23.9648 (Actor LR: 0.17, Critic LR: 0.58)
# New best value norm: 24.6083 (Actor LR: 0.17, Critic LR: 0.69)
# New best value norm: 24.7560 (Actor LR: 0.22, Critic LR: 0.74)
# New best value norm: 24.9660 (Actor LR: 0.22, Critic LR: 0.84)
# New best value norm: 25.0059 (Actor LR: 0.27, Critic LR: 0.74)
# New best value norm: 25.1738 (Actor LR: 0.32, Critic LR: 0.79)
# New best value norm: 25.5288 (Actor LR: 0.32, Critic LR: 0.84)
# New best value norm: 25.5550 (Actor LR: 0.37, Critic LR: 0.64)
# New best value norm: 25.9540 (Actor LR: 0.37, Critic LR: 0.69)
# New best value norm: 26.3718 (Actor LR: 0.37, Critic LR: 0.79)
# New best value norm: 26.7205 (Actor LR: 0.95, Critic LR: 0.84)
# Best Actor Learning Rate: 0.9478947368421053
# Best Critic Learning Rate: 0.8436842105263158
# Best Norm of Value Function: 26.72046475425772

# %%
# Hyperparameters for random search

# Number of training runs
total_training_runs = 400
num_random_samples = total_training_runs

# Learning rate range for random search
learning_rate_range = (0.01, 1.0)

# Function to randomly sample learning rates
def sample_learning_rate():
    return np.random.uniform(learning_rate_range[0], learning_rate_range[1])

# Create directories for saving plots and results if needed
# log_dir = "./tmp/actor_critics"
# os.makedirs(log_dir, exist_ok=True)

# Random search for hyper-parameter tuning
def random_search(mdp, num_runs, nb_episodes, timeout, render):
    best_actor_lr = None
    best_critic_lr = None
    best_value_norm = -np.inf
    sampled_actor_critic_pairs = []
    value_norms = []

    for run in range(num_random_samples):
        alpha_actor = sample_learning_rate()
        alpha_critic = sample_learning_rate()

        # Store the pair of learning rates
        sampled_actor_critic_pairs.append((alpha_actor, alpha_critic))

        # Store the final value norms over multiple repeats
        all_value_norms = []

        for repeat in range(num_runs):
            v, v_list, _ = Actor_Critic(mdp, nb_episodes, timeout, alpha_critic, alpha_actor, render)
            final_value_norm = np.linalg.norm(v)
            all_value_norms.append(final_value_norm)

        avg_value_norm = np.mean(all_value_norms)
        value_norms.append(avg_value_norm)

        # Update best hyperparameters if needed
        if avg_value_norm > best_value_norm:
            best_value_norm = avg_value_norm
            best_actor_lr = alpha_actor
            best_critic_lr = alpha_critic

            print(f"New best value norm: {best_value_norm:.4f} (Actor LR: {best_actor_lr:.2f}, Critic LR: {best_critic_lr:.2f})")

    return sampled_actor_critic_pairs, value_norms, best_actor_lr, best_critic_lr

# Function to create a heatmap
def plot_random_search_heatmap(sampled_pairs, value_norms):
    # Convert learning rates and value norms to 2D arrays for heatmap plotting
    actor_lrs = [pair[0] for pair in sampled_pairs]
    critic_lrs = [pair[1] for pair in sampled_pairs]

    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(actor_lrs, critic_lrs, c=value_norms, cmap='viridis', s=100, edgecolor='k')
    plt.colorbar(scatter, label='Norm of Value Function')
    plt.xlabel('Actor Learning Rate')
    plt.ylabel('Critic Learning Rate')
    plt.title('Random Search - Heatmap of Norm of Value Function')
    plt.tight_layout()
    plt.savefig(f"Random_Search_heatmap", bbox_inches="tight", dpi=100)
    plt.show()

# %%
sampled_pairs, rs_value_norms, best_actor_lr_random, best_critic_lr_random = random_search(
        mdp = env,
        num_runs=ac_params['nb_repeats'],
        nb_episodes=ac_params['nb_episodes'],
        timeout=ac_params['timeout'],
        render=ac_params['render']
    )

print("Best Actor Learning Rate (Random Search):", best_actor_lr_random)
print("Best Critic Learning Rate (Random Search):", best_critic_lr_random)

plot_random_search_heatmap(sampled_pairs, value_norms)
# Out:
# New best value norm: 7.3973 (Actor LR: 0.37, Critic LR: 0.15)
# New best value norm: 24.8940 (Actor LR: 0.33, Critic LR: 0.71)
# New best value norm: 24.9650 (Actor LR: 0.64, Critic LR: 0.66)
# New best value norm: 25.5270 (Actor LR: 0.79, Critic LR: 0.74)
# New best value norm: 25.8631 (Actor LR: 0.94, Critic LR: 0.87)
# New best value norm: 25.8782 (Actor LR: 0.89, Critic LR: 0.87)
# New best value norm: 26.1165 (Actor LR: 0.69, Critic LR: 0.81)
# New best value norm: 26.3232 (Actor LR: 0.99, Critic LR: 0.88)
# Best Actor Learning Rate (Random Search): 0.9937148630424131
# Best Critic Learning Rate (Random Search): 0.8774664996889192

# %%
# Hyperparameters for Bayesian optimization method (optuna)

import optuna

# Initialize a list to store alpha_actor, alpha_critic, and the norm of the value function
results = []

def objective(trial):
    # Define the search range for alpha_actor and alpha_critic
    alpha_actor = trial.suggest_float("alpha_actor", 0.01, 1.0)
    alpha_critic = trial.suggest_float("alpha_critic", 0.01, 1.0)

    # Call the Actor-Critic algorithm, passing in the tuned alpha_actor and alpha_critic
    mdp = env

    v, v_list, time_list = Actor_Critic(
        env,
        ac_params["nb_episodes"], 
        ac_params["timeout"], 
        ac_params["alpha_critic"], 
        ac_params["alpha_actor"],
        render=False,
        init_v=0,
        uniform=True,
    )

    # Calculate the norm
    norm_v = np.linalg.norm(v)
    
    # Save the alpha_actor, alpha_critic, and the corresponding norm
    results.append((alpha_actor, alpha_critic, norm_v))

    return norm_v

# %%
# Create a Study object and specify the optimization direction as maximization
study = optuna.create_study(direction="maximize")

# Run 400 times
study.optimize(objective, n_trials=400)

best_actor_lr_Bayes = study.best_params["alpha_actor"]
best_critic_lr_Bayes = study.best_params["alpha_critic"]

# print the results
print('best alpha_actor: ', best_actor_lr_Bayes)
print('best alpha_critic: ', best_critic_lr_Bayes)
print('best value: ', study.best_value)
# Out:
# [I 2024-10-01 22:24:38,864] A new study created in memory with name: no-name-f6138266-e29e-474d-aaa6-e6bc769f7225
# [I 2024-10-01 22:24:38,969] Trial 0 finished with value: 23.286444539399465 and parameters: {'alpha_actor': 0.18580245703925682, 'alpha_critic': 0.9498536485399123}. Best is trial 0 with value: 23.286444539399465.
# [I 2024-10-01 22:24:39,086] Trial 1 finished with value: 14.826730491603525 and parameters: {'alpha_actor': 0.15738563487915036, 'alpha_critic': 0.44807406551368206}. Best is trial 0 with value: 23.286444539399465.
# [I 2024-10-01 22:24:39,191] Trial 2 finished with value: 21.428131156391828 and parameters: {'alpha_actor': 0.5699829845105451, 'alpha_critic': 0.3074499670747158}. Best is trial 0 with value: 23.286444539399465.
# [I 2024-10-01 22:24:39,285] Trial 3 finished with value: 23.3156964961654 and parameters: {'alpha_actor': 0.15661249165731125, 'alpha_critic': 0.8758099408067458}. Best is trial 3 with value: 23.3156964961654.
# [I 2024-10-01 22:24:39,380] Trial 4 finished with value: 22.360348479308858 and parameters: {'alpha_actor': 0.4352645734318574, 'alpha_critic': 0.7747205593471134}. Best is trial 3 with value: 23.3156964961654.
# [I 2024-10-01 22:24:39,484] Trial 5 finished with value: 22.644711128046012 and parameters: {'alpha_actor': 0.2106338889582105, 'alpha_critic': 0.8507922579455284}. Best is trial 3 with value: 23.3156964961654.
# [I 2024-10-01 22:24:39,578] Trial 6 finished with value: 23.87370503058486 and parameters: {'alpha_actor': 0.8659528022670121, 'alpha_critic': 0.4047707946910033}. Best is trial 6 with value: 23.87370503058486.
# [I 2024-10-01 22:24:39,681] Trial 7 finished with value: 22.10681295614804 and parameters: {'alpha_actor': 0.2780483085564577, 'alpha_critic': 0.3964962066256729}. Best is trial 6 with value: 23.87370503058486.
# [I 2024-10-01 22:24:39,808] Trial 8 finished with value: 22.74351239647708 and parameters: {'alpha_actor': 0.49902666507064425, 'alpha_critic': 0.19322092960879292}. Best is trial 6 with value: 23.87370503058486.
# [I 2024-10-01 22:24:39,920] Trial 9 finished with value: 22.93948587545692 and parameters: {'alpha_actor': 0.40151922529994316, 'alpha_critic': 0.8950451896819897}. Best is trial 6 with value: 23.87370503058486.
# [I 2024-10-01 22:24:40,069] Trial 10 finished with value: 20.784565677458517 and parameters: {'alpha_actor': 0.9299257271424584, 'alpha_critic': 0.016091592815903943}. Best is trial 6 with value: 23.87370503058486.
# [I 2024-10-01 22:24:40,161] Trial 11 finished with value: 23.92882055030246 and parameters: {'alpha_actor': 0.8205161724308557, 'alpha_critic': 0.6377904186479442}. Best is trial 11 with value: 23.92882055030246.
# [I 2024-10-01 22:24:40,274] Trial 12 finished with value: 23.542778333279447 and parameters: {'alpha_actor': 0.8520521458578902, 'alpha_critic': 0.6527093988628844}. Best is trial 11 with value: 23.92882055030246.
# [I 2024-10-01 22:24:40,393] Trial 13 finished with value: 24.25341795376611 and parameters: {'alpha_actor': 0.7639947560999752, 'alpha_critic': 0.6288826844977509}. Best is trial 13 with value: 24.25341795376611.
# [I 2024-10-01 22:24:40,492] Trial 14 finished with value: 24.305228625216706 and parameters: {'alpha_actor': 0.6911504044876822, 'alpha_critic': 0.6248495562968209}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:40,608] Trial 15 finished with value: 22.039243518637313 and parameters: {'alpha_actor': 0.6800834540018126, 'alpha_critic': 0.6512119942201777}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:40,727] Trial 16 finished with value: 22.453828108736438 and parameters: {'alpha_actor': 0.6842733583418018, 'alpha_critic': 0.5721577420033798}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:40,844] Trial 17 finished with value: 23.91487497892742 and parameters: {'alpha_actor': 0.7119036752008331, 'alpha_critic': 0.7660038413180925}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:40,947] Trial 18 finished with value: 23.88673158880098 and parameters: {'alpha_actor': 0.5930201657808418, 'alpha_critic': 0.520241020169364}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:41,050] Trial 19 finished with value: 23.94685982573978 and parameters: {'alpha_actor': 0.9917825322426832, 'alpha_critic': 0.7162048874336401}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:41,172] Trial 20 finished with value: 22.06798594837022 and parameters: {'alpha_actor': 0.7686413218255358, 'alpha_critic': 0.30640338063622546}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:41,311] Trial 21 finished with value: 21.874363513081928 and parameters: {'alpha_actor': 0.963901744814526, 'alpha_critic': 0.7420518147802668}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:41,429] Trial 22 finished with value: 23.44516233787018 and parameters: {'alpha_actor': 0.9871890887343194, 'alpha_critic': 0.5563929810563786}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:41,532] Trial 23 finished with value: 23.808327896640968 and parameters: {'alpha_actor': 0.04427584826345726, 'alpha_critic': 0.7211663504181176}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:41,638] Trial 24 finished with value: 22.94044727638912 and parameters: {'alpha_actor': 0.7530820093744222, 'alpha_critic': 0.6462013740568875}. Best is trial 14 with value: 24.305228625216706.
# [I 2024-10-01 22:24:41,710] Trial 25 finished with value: 24.4569593843543 and parameters: {'alpha_actor': 0.8928258584051959, 'alpha_critic': 0.9839285541509826}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:41,811] Trial 26 finished with value: 23.094429753890417 and parameters: {'alpha_actor': 0.6083085868751066, 'alpha_critic': 0.9990713886606737}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:41,918] Trial 27 finished with value: 22.612478132585863 and parameters: {'alpha_actor': 0.8898082264315196, 'alpha_critic': 0.8227799507007918}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:42,022] Trial 28 finished with value: 23.96003335975559 and parameters: {'alpha_actor': 0.7562254465589, 'alpha_critic': 0.10254030684102361}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:42,142] Trial 29 finished with value: 21.537222275325757 and parameters: {'alpha_actor': 0.6458451147695793, 'alpha_critic': 0.9412536831711594}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:42,271] Trial 30 finished with value: 22.782150978417302 and parameters: {'alpha_actor': 0.8016199385557317, 'alpha_critic': 0.4852628231254831}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:42,426] Trial 31 finished with value: 21.234858435435267 and parameters: {'alpha_actor': 0.7515516186097314, 'alpha_critic': 0.13510569549609172}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:42,546] Trial 32 finished with value: 23.11167853486486 and parameters: {'alpha_actor': 0.8788374883349833, 'alpha_critic': 0.02111027599740689}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:42,662] Trial 33 finished with value: 23.843621334290656 and parameters: {'alpha_actor': 0.5269892767208071, 'alpha_critic': 0.3091844061118779}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:42,786] Trial 34 finished with value: 23.360055216782765 and parameters: {'alpha_actor': 0.7273261060676062, 'alpha_critic': 0.18634422793220834}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:42,932] Trial 35 finished with value: 21.174538007580807 and parameters: {'alpha_actor': 0.8081499176743311, 'alpha_critic': 0.5737691715109077}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,053] Trial 36 finished with value: 22.63381935106522 and parameters: {'alpha_actor': 0.6432065995963354, 'alpha_critic': 0.38097392731018076}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,169] Trial 37 finished with value: 22.32433875946523 and parameters: {'alpha_actor': 0.9298067869915408, 'alpha_critic': 0.8113587047550108}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,291] Trial 38 finished with value: 22.22071407698016 and parameters: {'alpha_actor': 0.5331236394577569, 'alpha_critic': 0.4435018986118223}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,391] Trial 39 finished with value: 23.40564914868029 and parameters: {'alpha_actor': 0.9191715884318407, 'alpha_critic': 0.09630446148916061}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,507] Trial 40 finished with value: 23.324733606228154 and parameters: {'alpha_actor': 0.41612001012036465, 'alpha_critic': 0.2837309843936485}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,613] Trial 41 finished with value: 23.264383249921753 and parameters: {'alpha_actor': 0.9782890966843076, 'alpha_critic': 0.7013337040519163}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,723] Trial 42 finished with value: 24.326920174156026 and parameters: {'alpha_actor': 0.8436001402919423, 'alpha_critic': 0.8932932936134199}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,841] Trial 43 finished with value: 22.31329970957333 and parameters: {'alpha_actor': 0.8403339341155279, 'alpha_critic': 0.9147347978679783}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:43,968] Trial 44 finished with value: 23.14194724114732 and parameters: {'alpha_actor': 0.7918917174112708, 'alpha_critic': 0.9859876893290279}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:44,084] Trial 45 finished with value: 22.663604013695874 and parameters: {'alpha_actor': 0.8779252211280778, 'alpha_critic': 0.8649455958575101}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:44,200] Trial 46 finished with value: 22.78308556867904 and parameters: {'alpha_actor': 0.3464018295229949, 'alpha_critic': 0.9535034158139223}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:44,309] Trial 47 finished with value: 22.597663933102748 and parameters: {'alpha_actor': 0.6984150059670869, 'alpha_critic': 0.8095533685716547}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:44,437] Trial 48 finished with value: 22.137806055660345 and parameters: {'alpha_actor': 0.6562375825183239, 'alpha_critic': 0.6139682602399126}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:44,573] Trial 49 finished with value: 23.06795904746203 and parameters: {'alpha_actor': 0.8332522833265101, 'alpha_critic': 0.8979749419948413}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:44,698] Trial 50 finished with value: 21.76586735880784 and parameters: {'alpha_actor': 0.7759092052302243, 'alpha_critic': 0.7763882511569031}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:44,807] Trial 51 finished with value: 22.951277606882403 and parameters: {'alpha_actor': 0.9424917351406041, 'alpha_critic': 0.6029969071918537}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:44,908] Trial 52 finished with value: 23.907037957123443 and parameters: {'alpha_actor': 0.9985143901182977, 'alpha_critic': 0.688032418919018}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:45,003] Trial 53 finished with value: 23.861406150595037 and parameters: {'alpha_actor': 0.8563746564757366, 'alpha_critic': 0.6758472319244825}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:45,107] Trial 54 finished with value: 23.08071447444892 and parameters: {'alpha_actor': 0.8930845100818855, 'alpha_critic': 0.5292844459726735}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:45,258] Trial 55 finished with value: 19.998203296272436 and parameters: {'alpha_actor': 0.9111029336497493, 'alpha_critic': 0.8405778720299187}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:45,382] Trial 56 finished with value: 21.800147052641016 and parameters: {'alpha_actor': 0.7381377945518788, 'alpha_critic': 0.7425896283204866}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:45,548] Trial 57 finished with value: 16.938418710566665 and parameters: {'alpha_actor': 0.8060569896036297, 'alpha_critic': 0.9493862218193504}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:45,658] Trial 58 finished with value: 23.164682397006352 and parameters: {'alpha_actor': 0.9465663230801803, 'alpha_critic': 0.458398622379217}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:45,794] Trial 59 finished with value: 22.369838281565677 and parameters: {'alpha_actor': 0.8471500691636984, 'alpha_critic': 0.597675614051914}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:45,919] Trial 60 finished with value: 21.59832805736302 and parameters: {'alpha_actor': 0.4573618587963692, 'alpha_critic': 0.7831230173959356}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,015] Trial 61 finished with value: 24.186230836379163 and parameters: {'alpha_actor': 0.7149340489592024, 'alpha_critic': 0.6501004162053654}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,119] Trial 62 finished with value: 23.429864222924017 and parameters: {'alpha_actor': 0.7165675200887268, 'alpha_critic': 0.6487873172469852}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,226] Trial 63 finished with value: 23.05852739625702 and parameters: {'alpha_actor': 0.6798179836844681, 'alpha_critic': 0.726698155670177}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,329] Trial 64 finished with value: 23.87392954948343 and parameters: {'alpha_actor': 0.746153665871004, 'alpha_critic': 0.5275665201961413}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,435] Trial 65 finished with value: 23.691122372829657 and parameters: {'alpha_actor': 0.6097428812488853, 'alpha_critic': 0.5585772064771429}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,527] Trial 66 finished with value: 24.167921201859553 and parameters: {'alpha_actor': 0.7721548504482529, 'alpha_critic': 0.8864737396088608}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,653] Trial 67 finished with value: 23.038019209304455 and parameters: {'alpha_actor': 0.7798276676537274, 'alpha_critic': 0.8955044142490645}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,741] Trial 68 finished with value: 23.439651270866698 and parameters: {'alpha_actor': 0.5819296449267886, 'alpha_critic': 0.9754586178524801}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:46,889] Trial 69 finished with value: 23.599399370541477 and parameters: {'alpha_actor': 0.6319557863229012, 'alpha_critic': 0.9137641294615265}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:47,042] Trial 70 finished with value: 22.371154131147648 and parameters: {'alpha_actor': 0.6715311390513666, 'alpha_critic': 0.8653317154511122}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:47,170] Trial 71 finished with value: 23.289483827402307 and parameters: {'alpha_actor': 0.8108550724670653, 'alpha_critic': 0.6277645392062919}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:47,310] Trial 72 finished with value: 21.261007381804607 and parameters: {'alpha_actor': 0.7005612981372152, 'alpha_critic': 0.7509487614215377}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:47,428] Trial 73 finished with value: 22.895905528620432 and parameters: {'alpha_actor': 0.8685606977888504, 'alpha_critic': 0.6755404064376979}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:47,509] Trial 74 finished with value: 24.138307581091794 and parameters: {'alpha_actor': 0.9113904156030829, 'alpha_critic': 0.8383106369884448}. Best is trial 25 with value: 24.4569593843543.
# [I 2024-10-01 22:24:47,607] Trial 75 finished with value: 25.067304459252394 and parameters: {'alpha_actor': 0.7730185568175547, 'alpha_critic': 0.9265403097172509}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:47,760] Trial 76 finished with value: 18.79777242784569 and parameters: {'alpha_actor': 0.8353874584453672, 'alpha_critic': 0.9279447899317627}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:47,861] Trial 77 finished with value: 24.329665607929567 and parameters: {'alpha_actor': 0.9098394290851324, 'alpha_critic': 0.8453693481978887}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:47,979] Trial 78 finished with value: 23.279773311952933 and parameters: {'alpha_actor': 0.7739679097388146, 'alpha_critic': 0.9588259231130434}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:48,125] Trial 79 finished with value: 20.49380514348974 and parameters: {'alpha_actor': 0.7317057123127093, 'alpha_critic': 0.8809204921163565}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:48,246] Trial 80 finished with value: 22.93331601077829 and parameters: {'alpha_actor': 0.954423755589464, 'alpha_critic': 0.7970132726225723}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:48,354] Trial 81 finished with value: 23.135646089582004 and parameters: {'alpha_actor': 0.8949837144949527, 'alpha_critic': 0.8410888252916732}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:48,486] Trial 82 finished with value: 21.974587968002126 and parameters: {'alpha_actor': 0.9165391256723683, 'alpha_critic': 0.8378435566686991}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:48,595] Trial 83 finished with value: 23.983730685674935 and parameters: {'alpha_actor': 0.821578288921588, 'alpha_critic': 0.9757298268684576}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:48,733] Trial 84 finished with value: 22.30283751618557 and parameters: {'alpha_actor': 0.8623124892023464, 'alpha_critic': 0.8789525077534951}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:48,837] Trial 85 finished with value: 23.25383267367238 and parameters: {'alpha_actor': 0.11918294986015332, 'alpha_critic': 0.9934366361015008}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:48,967] Trial 86 finished with value: 22.194540007985967 and parameters: {'alpha_actor': 0.9062873987927439, 'alpha_critic': 0.9187827655874379}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:49,082] Trial 87 finished with value: 23.861835702256776 and parameters: {'alpha_actor': 0.7604862824842087, 'alpha_critic': 0.859920569850553}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:49,212] Trial 88 finished with value: 21.765936817365027 and parameters: {'alpha_actor': 0.7905376237119898, 'alpha_critic': 0.9364072852653407}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:49,325] Trial 89 finished with value: 21.966241023965893 and parameters: {'alpha_actor': 0.8374735878885057, 'alpha_critic': 0.8209863489082179}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:49,475] Trial 90 finished with value: 22.111455782306503 and parameters: {'alpha_actor': 0.7074596630552881, 'alpha_critic': 0.8936279438353895}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:49,591] Trial 91 finished with value: 23.117757552414883 and parameters: {'alpha_actor': 0.8192716928918764, 'alpha_critic': 0.975317836951969}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:49,719] Trial 92 finished with value: 23.512089411577502 and parameters: {'alpha_actor': 0.8806946816494228, 'alpha_critic': 0.968433335645955}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:49,903] Trial 93 finished with value: 19.57548905402984 and parameters: {'alpha_actor': 0.8160589064121174, 'alpha_critic': 0.9411076075290913}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,019] Trial 94 finished with value: 22.236253210193674 and parameters: {'alpha_actor': 0.7944193220415381, 'alpha_critic': 0.9946327470962236}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,133] Trial 95 finished with value: 22.93554731842092 and parameters: {'alpha_actor': 0.9308239465468906, 'alpha_critic': 0.9121975788192621}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,256] Trial 96 finished with value: 22.356560150068326 and parameters: {'alpha_actor': 0.9705298303992042, 'alpha_critic': 0.5883149872295352}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,362] Trial 97 finished with value: 23.55796983883117 and parameters: {'alpha_actor': 0.5487985477997199, 'alpha_critic': 0.7954234507321116}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,492] Trial 98 finished with value: 21.852975803317033 and parameters: {'alpha_actor': 0.8531509577367566, 'alpha_critic': 0.7635259055688409}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,632] Trial 99 finished with value: 21.270181886592614 and parameters: {'alpha_actor': 0.7583785291383849, 'alpha_critic': 0.4844711443570754}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,733] Trial 100 finished with value: 22.931375648624094 and parameters: {'alpha_actor': 0.7351759610324453, 'alpha_critic': 0.8933298472992741}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,842] Trial 101 finished with value: 23.151098251482384 and parameters: {'alpha_actor': 0.7730059289227648, 'alpha_critic': 0.27128302903000046}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:50,940] Trial 102 finished with value: 23.59520749108304 and parameters: {'alpha_actor': 0.8255681811361578, 'alpha_critic': 0.33866926729732527}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,062] Trial 103 finished with value: 22.427275495102943 and parameters: {'alpha_actor': 0.7248169787697545, 'alpha_critic': 0.22683341776607668}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,150] Trial 104 finished with value: 23.67148948853268 and parameters: {'alpha_actor': 0.6741090752728984, 'alpha_critic': 0.1132236650757235}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,260] Trial 105 finished with value: 23.672343824552886 and parameters: {'alpha_actor': 0.8729221458169579, 'alpha_critic': 0.9596781962939327}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,370] Trial 106 finished with value: 23.40403155398723 and parameters: {'alpha_actor': 0.79311313357413, 'alpha_critic': 0.8516912500934696}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,480] Trial 107 finished with value: 23.111900644276925 and parameters: {'alpha_actor': 0.7529170179468734, 'alpha_critic': 0.06435946876932541}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,617] Trial 108 finished with value: 21.44765856608102 and parameters: {'alpha_actor': 0.8967867505951216, 'alpha_critic': 0.7133716275778299}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,719] Trial 109 finished with value: 24.144659592365386 and parameters: {'alpha_actor': 0.2802516156210032, 'alpha_critic': 0.6702816875219314}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,835] Trial 110 finished with value: 23.360869675882846 and parameters: {'alpha_actor': 0.2199466029250392, 'alpha_critic': 0.6644456367425624}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:51,946] Trial 111 finished with value: 22.357047674149385 and parameters: {'alpha_actor': 0.3531833066487221, 'alpha_critic': 0.6265357675846034}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,036] Trial 112 finished with value: 23.793169707049465 and parameters: {'alpha_actor': 0.49198292471601446, 'alpha_critic': 0.6918592899467505}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,147] Trial 113 finished with value: 23.258902509088415 and parameters: {'alpha_actor': 0.6937326986733894, 'alpha_critic': 0.504710973049272}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,236] Trial 114 finished with value: 24.03893701294579 and parameters: {'alpha_actor': 0.11563190363468356, 'alpha_critic': 0.9267330547515022}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,346] Trial 115 finished with value: 22.916365510198723 and parameters: {'alpha_actor': 0.037253290757219365, 'alpha_critic': 0.9371171016181413}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,437] Trial 116 finished with value: 23.51438436951961 and parameters: {'alpha_actor': 0.08740472981929012, 'alpha_critic': 0.8764244172363166}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,541] Trial 117 finished with value: 23.181725324688227 and parameters: {'alpha_actor': 0.3779420521834616, 'alpha_critic': 0.9110199544001465}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,641] Trial 118 finished with value: 23.58018230476119 and parameters: {'alpha_actor': 0.2643035140776034, 'alpha_critic': 0.8353470076222069}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,766] Trial 119 finished with value: 22.299194351000075 and parameters: {'alpha_actor': 0.29612613343924216, 'alpha_critic': 0.5464172726523726}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:52,899] Trial 120 finished with value: 20.67044354382983 and parameters: {'alpha_actor': 0.18787480762562692, 'alpha_critic': 0.5790400361792513}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,017] Trial 121 finished with value: 23.07713998039342 and parameters: {'alpha_actor': 0.10843059260962495, 'alpha_critic': 0.6426468370165157}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,137] Trial 122 finished with value: 22.78857872250732 and parameters: {'alpha_actor': 0.8437164586998405, 'alpha_critic': 0.6106227485913482}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,243] Trial 123 finished with value: 23.33410063774554 and parameters: {'alpha_actor': 0.9307011328410127, 'alpha_critic': 0.9792435696142701}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,354] Trial 124 finished with value: 22.876283497457116 and parameters: {'alpha_actor': 0.013455784554401828, 'alpha_critic': 0.9291639538864545}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,436] Trial 125 finished with value: 23.906192009888297 and parameters: {'alpha_actor': 0.8066332607271351, 'alpha_critic': 0.9993100111411337}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,529] Trial 126 finished with value: 22.417824461300622 and parameters: {'alpha_actor': 0.6243205921059419, 'alpha_critic': 0.9540329625345196}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,673] Trial 127 finished with value: 22.64825383256112 and parameters: {'alpha_actor': 0.6618958713927235, 'alpha_critic': 0.8993076900675447}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,785] Trial 128 finished with value: 23.038962092646713 and parameters: {'alpha_actor': 0.722332892653488, 'alpha_critic': 0.8700531140705643}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:53,913] Trial 129 finished with value: 21.11589657112289 and parameters: {'alpha_actor': 0.779387766522657, 'alpha_critic': 0.8212717984394293}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,037] Trial 130 finished with value: 22.26262423858588 and parameters: {'alpha_actor': 0.15269711275643885, 'alpha_critic': 0.9511756698450171}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,136] Trial 131 finished with value: 23.010422811500167 and parameters: {'alpha_actor': 0.9917922578922549, 'alpha_critic': 0.7316564372918035}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,245] Trial 132 finished with value: 22.86669207750248 and parameters: {'alpha_actor': 0.9536883548471125, 'alpha_critic': 0.7007309336398261}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,348] Trial 133 finished with value: 23.162324281779586 and parameters: {'alpha_actor': 0.9689221424421772, 'alpha_critic': 0.7979007075554858}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,451] Trial 134 finished with value: 23.251651274787523 and parameters: {'alpha_actor': 0.8608930592203988, 'alpha_critic': 0.6678280448501264}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,574] Trial 135 finished with value: 22.74762223703902 and parameters: {'alpha_actor': 0.9096274384380175, 'alpha_critic': 0.6290094674322922}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,687] Trial 136 finished with value: 22.891042501446446 and parameters: {'alpha_actor': 0.7461964689950147, 'alpha_critic': 0.9259413385968543}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,773] Trial 137 finished with value: 23.720938090154828 and parameters: {'alpha_actor': 0.8850346129158226, 'alpha_critic': 0.7542985041603519}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:54,879] Trial 138 finished with value: 24.146661893420283 and parameters: {'alpha_actor': 0.8300112163144824, 'alpha_critic': 0.41291535414854524}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:55,047] Trial 139 finished with value: 18.53735613646801 and parameters: {'alpha_actor': 0.8188232994816095, 'alpha_critic': 0.3785917023584262}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:55,171] Trial 140 finished with value: 21.610301348887013 and parameters: {'alpha_actor': 0.7692816809738379, 'alpha_critic': 0.19106387604571679}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:55,310] Trial 141 finished with value: 23.544282194559106 and parameters: {'alpha_actor': 0.7928332140139795, 'alpha_critic': 0.6559438544947521}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:55,418] Trial 142 finished with value: 23.245582388161093 and parameters: {'alpha_actor': 0.838279335211279, 'alpha_critic': 0.4199478315349874}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:55,563] Trial 143 finished with value: 21.498579668625514 and parameters: {'alpha_actor': 0.8659586322973836, 'alpha_critic': 0.7149817890409086}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:55,671] Trial 144 finished with value: 24.372061574331283 and parameters: {'alpha_actor': 0.9287696027737878, 'alpha_critic': 0.16559354322579922}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:55,783] Trial 145 finished with value: 23.30422263461386 and parameters: {'alpha_actor': 0.9102509489170668, 'alpha_critic': 0.14784266806036447}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:55,908] Trial 146 finished with value: 22.521594225719454 and parameters: {'alpha_actor': 0.7100478623882853, 'alpha_critic': 0.0694194686104061}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,055] Trial 147 finished with value: 21.11616012717833 and parameters: {'alpha_actor': 0.9381953459391322, 'alpha_critic': 0.2196454646892636}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,167] Trial 148 finished with value: 23.390389983612028 and parameters: {'alpha_actor': 0.8256361459407257, 'alpha_critic': 0.07410737960802029}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,264] Trial 149 finished with value: 23.211181531494297 and parameters: {'alpha_actor': 0.23509353495290458, 'alpha_critic': 0.1306004714235929}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,378] Trial 150 finished with value: 22.29436777359584 and parameters: {'alpha_actor': 0.4518319806232399, 'alpha_critic': 0.02666916724174352}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,516] Trial 151 finished with value: 22.473873432279163 and parameters: {'alpha_actor': 0.8901786136686544, 'alpha_critic': 0.5985703303890031}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,628] Trial 152 finished with value: 23.18283484890162 and parameters: {'alpha_actor': 0.978822323060057, 'alpha_critic': 0.8558141781523442}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,761] Trial 153 finished with value: 23.24526026535162 and parameters: {'alpha_actor': 0.9397496233872756, 'alpha_critic': 0.1510450372776637}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,843] Trial 154 finished with value: 24.313739171561437 and parameters: {'alpha_actor': 0.9206095580774133, 'alpha_critic': 0.6807467784612272}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:56,947] Trial 155 finished with value: 23.083948195948135 and parameters: {'alpha_actor': 0.8727464076261324, 'alpha_critic': 0.5590154109008422}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:57,045] Trial 156 finished with value: 24.45057981059363 and parameters: {'alpha_actor': 0.9246183430525056, 'alpha_critic': 0.6839242319538941}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:57,163] Trial 157 finished with value: 22.128328810145945 and parameters: {'alpha_actor': 0.9113743372883113, 'alpha_critic': 0.6806846808913577}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:57,260] Trial 158 finished with value: 24.10400939947162 and parameters: {'alpha_actor': 0.958065109438057, 'alpha_critic': 0.6421417984280897}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:57,414] Trial 159 finished with value: 21.976452375822625 and parameters: {'alpha_actor': 0.9598951464943772, 'alpha_critic': 0.6405177755672715}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:57,694] Trial 160 finished with value: 21.70230816630636 and parameters: {'alpha_actor': 0.9310400359466384, 'alpha_critic': 0.6169161212596859}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:57,821] Trial 161 finished with value: 23.361780688558685 and parameters: {'alpha_actor': 0.9503782780239145, 'alpha_critic': 0.6916243615177584}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:57,943] Trial 162 finished with value: 22.52193263369949 and parameters: {'alpha_actor': 0.9201989661421638, 'alpha_critic': 0.6573242938729623}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:58,083] Trial 163 finished with value: 22.07227365229278 and parameters: {'alpha_actor': 0.8987454374913568, 'alpha_critic': 0.9791345388373752}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:58,187] Trial 164 finished with value: 23.80352023178586 and parameters: {'alpha_actor': 0.8838496905332893, 'alpha_critic': 0.8860894339917864}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:58,326] Trial 165 finished with value: 22.20017515383084 and parameters: {'alpha_actor': 0.853174107729783, 'alpha_critic': 0.6737131236767291}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:58,440] Trial 166 finished with value: 23.34367052369425 and parameters: {'alpha_actor': 0.9257765098320924, 'alpha_critic': 0.9038184207393688}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:58,577] Trial 167 finished with value: 22.488764496309077 and parameters: {'alpha_actor': 0.9715486566098988, 'alpha_critic': 0.6362752971466115}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:58,777] Trial 168 finished with value: 16.69535175538322 and parameters: {'alpha_actor': 0.9939684545098559, 'alpha_critic': 0.5776212181323673}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:58,915] Trial 169 finished with value: 21.90986681160677 and parameters: {'alpha_actor': 0.28938962484475617, 'alpha_critic': 0.7066958633839459}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:59,017] Trial 170 finished with value: 24.312729643361767 and parameters: {'alpha_actor': 0.8347441481207897, 'alpha_critic': 0.9646591153056049}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:59,166] Trial 171 finished with value: 21.69310142810977 and parameters: {'alpha_actor': 0.7996117349272462, 'alpha_critic': 0.970404771434347}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:59,335] Trial 172 finished with value: 20.34586090478888 and parameters: {'alpha_actor': 0.8473870711028698, 'alpha_critic': 0.9473645372499665}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:59,473] Trial 173 finished with value: 21.328967738354358 and parameters: {'alpha_actor': 0.8245299018418175, 'alpha_critic': 0.9261653200522499}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:59,659] Trial 174 finished with value: 18.889653842766265 and parameters: {'alpha_actor': 0.8952632438638839, 'alpha_critic': 0.9986288247530891}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:59,768] Trial 175 finished with value: 24.435326673643896 and parameters: {'alpha_actor': 0.8710584072437607, 'alpha_critic': 0.9679307355083457}. Best is trial 75 with value: 25.067304459252394.
# [I 2024-10-01 22:24:59,854] Trial 176 finished with value: 25.278320955654458 and parameters: {'alpha_actor': 0.8640126169086411, 'alpha_critic': 0.912471717893264}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:00,020] Trial 177 finished with value: 21.10453072074649 and parameters: {'alpha_actor': 0.8780921690210397, 'alpha_critic': 0.732813942672252}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:00,175] Trial 178 finished with value: 22.375539442405145 and parameters: {'alpha_actor': 0.8624496629245987, 'alpha_critic': 0.6055869145030482}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:00,360] Trial 179 finished with value: 22.784795272841244 and parameters: {'alpha_actor': 0.9123175042837991, 'alpha_critic': 0.9082599028881764}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:00,491] Trial 180 finished with value: 21.545239130475526 and parameters: {'alpha_actor': 0.9526038642847704, 'alpha_critic': 0.9623567150199381}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:00,741] Trial 181 finished with value: 23.118594307166127 and parameters: {'alpha_actor': 0.8955540521334314, 'alpha_critic': 0.932639157605834}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:00,891] Trial 182 finished with value: 23.944836942927274 and parameters: {'alpha_actor': 0.9265654825119365, 'alpha_critic': 0.8641471395493523}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:01,045] Trial 183 finished with value: 21.948008905627944 and parameters: {'alpha_actor': 0.8442400831167919, 'alpha_critic': 0.8809319377253663}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:01,172] Trial 184 finished with value: 22.442312166575427 and parameters: {'alpha_actor': 0.870819716116229, 'alpha_critic': 0.6560977346129162}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:01,277] Trial 185 finished with value: 24.260734577501367 and parameters: {'alpha_actor': 0.3112697884891207, 'alpha_critic': 0.9489164102635278}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:01,393] Trial 186 finished with value: 23.770477373175137 and parameters: {'alpha_actor': 0.8066310440619806, 'alpha_critic': 0.9077303308894336}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:01,498] Trial 187 finished with value: 24.340588565905236 and parameters: {'alpha_actor': 0.764466443785713, 'alpha_critic': 0.9476759984447498}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:01,640] Trial 188 finished with value: 20.174774684934015 and parameters: {'alpha_actor': 0.34360077147925544, 'alpha_critic': 0.9475958361620005}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:01,792] Trial 189 finished with value: 22.954383969312932 and parameters: {'alpha_actor': 0.3161853272047754, 'alpha_critic': 0.9648588936467292}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:01,917] Trial 190 finished with value: 22.385803380778068 and parameters: {'alpha_actor': 0.7411495628661815, 'alpha_critic': 0.936632051201875}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:02,020] Trial 191 finished with value: 23.756764445067038 and parameters: {'alpha_actor': 0.7870974125854877, 'alpha_critic': 0.836308212931432}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:02,201] Trial 192 finished with value: 23.07963093346879 and parameters: {'alpha_actor': 0.2611671971890701, 'alpha_critic': 0.9813288611632988}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:02,418] Trial 193 finished with value: 22.376362337950525 and parameters: {'alpha_actor': 0.7825238596245182, 'alpha_critic': 0.894220274300114}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:02,545] Trial 194 finished with value: 22.29167468031097 and parameters: {'alpha_actor': 0.7627220248911759, 'alpha_critic': 0.4778537462564651}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:02,667] Trial 195 finished with value: 23.248918209080085 and parameters: {'alpha_actor': 0.9373016749480377, 'alpha_critic': 0.683913693514753}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:02,777] Trial 196 finished with value: 22.918121855341603 and parameters: {'alpha_actor': 0.9068761445893477, 'alpha_critic': 0.6247892899689206}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:02,921] Trial 197 finished with value: 22.94896104490389 and parameters: {'alpha_actor': 0.7195107498673392, 'alpha_critic': 0.9444751191688198}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:03,072] Trial 198 finished with value: 21.665813979826552 and parameters: {'alpha_actor': 0.8374366291533568, 'alpha_critic': 0.9164909003282816}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:03,201] Trial 199 finished with value: 21.859141614598173 and parameters: {'alpha_actor': 0.7466591481391174, 'alpha_critic': 0.34596134473022466}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:03,327] Trial 200 finished with value: 23.881041389629566 and parameters: {'alpha_actor': 0.8877648186775315, 'alpha_critic': 0.9572423446923389}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:03,437] Trial 201 finished with value: 24.169692966407563 and parameters: {'alpha_actor': 0.18075018414452032, 'alpha_critic': 0.919455128777069}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:03,549] Trial 202 finished with value: 23.59767657810271 and parameters: {'alpha_actor': 0.18665346238282554, 'alpha_critic': 0.8753609570843806}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:03,695] Trial 203 finished with value: 20.763571312903107 and parameters: {'alpha_actor': 0.487955129211571, 'alpha_critic': 0.9230896562150545}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:03,838] Trial 204 finished with value: 21.29382120116293 and parameters: {'alpha_actor': 0.24634080840822542, 'alpha_critic': 0.6417989703781353}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:03,981] Trial 205 finished with value: 22.380098472264063 and parameters: {'alpha_actor': 0.1640456587262588, 'alpha_critic': 0.9771300391522526}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:04,139] Trial 206 finished with value: 20.52619337953463 and parameters: {'alpha_actor': 0.6934093585983362, 'alpha_critic': 0.8993181949599085}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:04,292] Trial 207 finished with value: 22.319292130308114 and parameters: {'alpha_actor': 0.21167364578815318, 'alpha_critic': 0.2570552472736878}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:04,439] Trial 208 finished with value: 21.845143131646186 and parameters: {'alpha_actor': 0.8731866199491651, 'alpha_critic': 0.6728425860590757}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:04,584] Trial 209 finished with value: 21.22404473701583 and parameters: {'alpha_actor': 0.37346161172212466, 'alpha_critic': 0.7777732364493206}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:04,712] Trial 210 finished with value: 23.87851350548679 and parameters: {'alpha_actor': 0.8576285555226828, 'alpha_critic': 0.8568217288793892}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:04,866] Trial 211 finished with value: 22.1303336882072 and parameters: {'alpha_actor': 0.11284171392084469, 'alpha_critic': 0.9276378303400004}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:05,023] Trial 212 finished with value: 20.059380071724277 and parameters: {'alpha_actor': 0.0658491118147707, 'alpha_critic': 0.9468379856840513}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:05,161] Trial 213 finished with value: 21.536510088330918 and parameters: {'alpha_actor': 0.14395536952103832, 'alpha_critic': 0.9623019030109904}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:05,311] Trial 214 finished with value: 21.83012658910369 and parameters: {'alpha_actor': 0.16864697954015637, 'alpha_critic': 0.9165661446926409}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:05,441] Trial 215 finished with value: 21.925154965139697 and parameters: {'alpha_actor': 0.7686011652827051, 'alpha_critic': 0.890756802578849}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:05,551] Trial 216 finished with value: 23.809744691285374 and parameters: {'alpha_actor': 0.07454292287388799, 'alpha_critic': 0.9890798961371761}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:05,643] Trial 217 finished with value: 24.530978019277924 and parameters: {'alpha_actor': 0.9221506485440836, 'alpha_critic': 0.9374866672704221}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:05,790] Trial 218 finished with value: 23.091631016011423 and parameters: {'alpha_actor': 0.916878997240192, 'alpha_critic': 0.9369009013860485}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:05,916] Trial 219 finished with value: 22.29848739924962 and parameters: {'alpha_actor': 0.9510481270384147, 'alpha_critic': 0.9623132262986568}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:06,069] Trial 220 finished with value: 21.18966684768896 and parameters: {'alpha_actor': 0.9278443679320113, 'alpha_critic': 0.6574361083860312}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:06,185] Trial 221 finished with value: 22.70235474499177 and parameters: {'alpha_actor': 0.1275665651595082, 'alpha_critic': 0.9133765869197902}. Best is trial 176 with value: 25.278320955654458.
# ...
# [I 2024-10-01 22:25:20,595] Trial 327 finished with value: 22.2149461519931 and parameters: {'alpha_actor': 0.24666321574299152, 'alpha_critic': 0.47518710609252535}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:20,737] Trial 328 finished with value: 22.051330488737072 and parameters: {'alpha_actor': 0.7019602694337773, 'alpha_critic': 0.8108754082420558}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:20,830] Trial 329 finished with value: 24.05821426267946 and parameters: {'alpha_actor': 0.8028924074701633, 'alpha_critic': 0.87932508728008}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:20,957] Trial 330 finished with value: 22.99385104077838 and parameters: {'alpha_actor': 0.9082477679863215, 'alpha_critic': 0.6018445232723668}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:21,089] Trial 331 finished with value: 20.801944690135475 and parameters: {'alpha_actor': 0.8851002639512973, 'alpha_critic': 0.9729484503682638}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:21,228] Trial 332 finished with value: 22.68303244023164 and parameters: {'alpha_actor': 0.7464041476294828, 'alpha_critic': 0.9253150358995306}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:21,349] Trial 333 finished with value: 23.773346676412196 and parameters: {'alpha_actor': 0.8555261264806329, 'alpha_critic': 0.6544659605269119}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:21,458] Trial 334 finished with value: 23.419492002432886 and parameters: {'alpha_actor': 0.8327476343886747, 'alpha_critic': 0.33205021976746585}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:21,588] Trial 335 finished with value: 23.95377648205801 and parameters: {'alpha_actor': 0.7698894819529536, 'alpha_critic': 0.9461227488091962}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:21,722] Trial 336 finished with value: 22.800679879727532 and parameters: {'alpha_actor': 0.9273998168097665, 'alpha_critic': 0.9026325436401283}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:21,845] Trial 337 finished with value: 23.18967033058132 and parameters: {'alpha_actor': 0.7239244706797031, 'alpha_critic': 0.9491638451172308}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,003] Trial 338 finished with value: 22.22612682426486 and parameters: {'alpha_actor': 0.8092953509306169, 'alpha_critic': 0.7286374944142693}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,150] Trial 339 finished with value: 22.883364380451585 and parameters: {'alpha_actor': 0.8685163906593053, 'alpha_critic': 0.9846211150387421}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,272] Trial 340 finished with value: 22.56937569943968 and parameters: {'alpha_actor': 0.8973327800696036, 'alpha_critic': 0.6789082424948815}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,398] Trial 341 finished with value: 22.840073948343875 and parameters: {'alpha_actor': 0.7865773480536933, 'alpha_critic': 0.17185108604750987}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,506] Trial 342 finished with value: 23.462890260259712 and parameters: {'alpha_actor': 0.5541848904799652, 'alpha_critic': 0.6257407122397133}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,636] Trial 343 finished with value: 22.65501875248045 and parameters: {'alpha_actor': 0.8423936493780336, 'alpha_critic': 0.9191014766098466}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,753] Trial 344 finished with value: 23.046131657991232 and parameters: {'alpha_actor': 0.9336197077208563, 'alpha_critic': 0.42503088081452256}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,866] Trial 345 finished with value: 23.876916594839738 and parameters: {'alpha_actor': 0.6826874729401913, 'alpha_critic': 0.558350804907778}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:22,957] Trial 346 finished with value: 24.133640920370862 and parameters: {'alpha_actor': 0.8198192469294941, 'alpha_critic': 0.8796594849872272}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:23,067] Trial 347 finished with value: 23.9417794178032 and parameters: {'alpha_actor': 0.7437307783391953, 'alpha_critic': 0.6999658252886117}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:23,204] Trial 348 finished with value: 23.563956300109716 and parameters: {'alpha_actor': 0.20261979027726595, 'alpha_critic': 0.9561443728147985}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:23,318] Trial 349 finished with value: 23.245718668234566 and parameters: {'alpha_actor': 0.9117128763953007, 'alpha_critic': 0.9326433717200038}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:23,428] Trial 350 finished with value: 23.758280844311937 and parameters: {'alpha_actor': 0.7101304339760961, 'alpha_critic': 0.8585263411462092}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:23,544] Trial 351 finished with value: 24.059228906530645 and parameters: {'alpha_actor': 0.1693549970365526, 'alpha_critic': 0.8983252243779833}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:23,648] Trial 352 finished with value: 23.805550728723276 and parameters: {'alpha_actor': 0.8660996030155461, 'alpha_critic': 0.976076951562715}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:23,759] Trial 353 finished with value: 23.319106299719877 and parameters: {'alpha_actor': 0.6538682626451702, 'alpha_critic': 0.9190489724857893}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:23,895] Trial 354 finished with value: 21.84748092242514 and parameters: {'alpha_actor': 0.8903280621939236, 'alpha_critic': 0.776517383431376}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:24,035] Trial 355 finished with value: 21.189725745064266 and parameters: {'alpha_actor': 0.7967020926920843, 'alpha_critic': 0.9415775395008117}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:24,136] Trial 356 finished with value: 22.866342675578803 and parameters: {'alpha_actor': 0.0424658727356218, 'alpha_critic': 0.5134988082410108}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:24,238] Trial 357 finished with value: 23.323619599093217 and parameters: {'alpha_actor': 0.6336719891200551, 'alpha_critic': 0.9973803624062223}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:24,467] Trial 358 finished with value: 22.664468634161103 and parameters: {'alpha_actor': 0.7572267435907982, 'alpha_critic': 0.6479190235531089}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:24,592] Trial 359 finished with value: 24.12178346312437 and parameters: {'alpha_actor': 0.9761019280657094, 'alpha_critic': 0.9617423808348473}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:24,829] Trial 360 finished with value: 23.421750337254302 and parameters: {'alpha_actor': 0.9468811667798732, 'alpha_critic': 0.8813374419985407}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:24,978] Trial 361 finished with value: 23.682435791790798 and parameters: {'alpha_actor': 0.36369424133876527, 'alpha_critic': 0.8377763216687604}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:25,070] Trial 362 finished with value: 24.61956570045431 and parameters: {'alpha_actor': 0.8399457638325423, 'alpha_critic': 0.6668884744534873}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:25,226] Trial 363 finished with value: 22.684257681205146 and parameters: {'alpha_actor': 0.8404667528993941, 'alpha_critic': 0.6146594944457986}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:25,325] Trial 364 finished with value: 23.324315858179624 and parameters: {'alpha_actor': 0.8255809339563114, 'alpha_critic': 0.7493774142360876}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:25,438] Trial 365 finished with value: 23.85712706408711 and parameters: {'alpha_actor': 0.8525899670725604, 'alpha_critic': 0.9059836559115787}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:25,589] Trial 366 finished with value: 23.023554989840534 and parameters: {'alpha_actor': 0.8816602519218698, 'alpha_critic': 0.9342634134311398}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:25,731] Trial 367 finished with value: 21.79465341136492 and parameters: {'alpha_actor': 0.8088464920393534, 'alpha_critic': 0.95666808717531}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:25,857] Trial 368 finished with value: 22.789279666678397 and parameters: {'alpha_actor': 0.01624869894242742, 'alpha_critic': 0.5864671297248923}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:25,982] Trial 369 finished with value: 23.14446630118499 and parameters: {'alpha_actor': 0.8631490694054353, 'alpha_critic': 0.6685345890348603}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:26,096] Trial 370 finished with value: 24.03256938737178 and parameters: {'alpha_actor': 0.7830917455070737, 'alpha_critic': 0.9197910573813254}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:26,209] Trial 371 finished with value: 23.434494258897594 and parameters: {'alpha_actor': 0.8333079618186089, 'alpha_critic': 0.8609454858777088}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:26,350] Trial 372 finished with value: 22.68098013923679 and parameters: {'alpha_actor': 0.7351390185507425, 'alpha_critic': 0.8937833557135599}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:26,470] Trial 373 finished with value: 23.000096646121513 and parameters: {'alpha_actor': 0.9181731083434566, 'alpha_critic': 0.012665290218580594}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:26,648] Trial 374 finished with value: 22.458926462420873 and parameters: {'alpha_actor': 0.87401077783595, 'alpha_critic': 0.9769569461189744}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:26,747] Trial 375 finished with value: 23.706016939277454 and parameters: {'alpha_actor': 0.7744459332641358, 'alpha_critic': 0.9438515505933744}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:26,880] Trial 376 finished with value: 23.293199758514724 and parameters: {'alpha_actor': 0.8113673642117126, 'alpha_critic': 0.803007311276863}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:27,000] Trial 377 finished with value: 22.629207095431436 and parameters: {'alpha_actor': 0.8470286724108201, 'alpha_critic': 0.7039274210015312}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:27,170] Trial 378 finished with value: 24.37606681308214 and parameters: {'alpha_actor': 0.8889721305506184, 'alpha_critic': 0.12199815995086677}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:27,317] Trial 379 finished with value: 21.555559948471497 and parameters: {'alpha_actor': 0.8993784325000082, 'alpha_critic': 0.6358835223037017}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:27,429] Trial 380 finished with value: 23.921612042985043 and parameters: {'alpha_actor': 0.9141018885868805, 'alpha_critic': 0.9178487341290374}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:27,534] Trial 381 finished with value: 23.786782012366974 and parameters: {'alpha_actor': 0.8888668156059598, 'alpha_critic': 0.10675796957836244}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:27,649] Trial 382 finished with value: 24.026302435267077 and parameters: {'alpha_actor': 0.9483164363849824, 'alpha_critic': 0.08723313252672465}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:27,778] Trial 383 finished with value: 22.853806210204816 and parameters: {'alpha_actor': 0.9255956579609251, 'alpha_critic': 0.15657508160611047}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:27,934] Trial 384 finished with value: 24.12686933858065 and parameters: {'alpha_actor': 0.8825531629033931, 'alpha_critic': 0.9651908555378547}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:28,099] Trial 385 finished with value: 22.774273586431853 and parameters: {'alpha_actor': 0.7049627602863553, 'alpha_critic': 0.8749145262600266}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:28,311] Trial 386 finished with value: 23.23796524413305 and parameters: {'alpha_actor': 0.9040372787873866, 'alpha_critic': 0.9479881522179737}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:28,421] Trial 387 finished with value: 23.350322908467884 and parameters: {'alpha_actor': 0.7561023699710433, 'alpha_critic': 0.12192922811155149}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:28,532] Trial 388 finished with value: 23.46212593255477 and parameters: {'alpha_actor': 0.865901679685912, 'alpha_critic': 0.048368723277289694}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:28,723] Trial 389 finished with value: 21.86349765889597 and parameters: {'alpha_actor': 0.675799730822096, 'alpha_critic': 0.8976830496143845}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:28,828] Trial 390 finished with value: 24.25083744911879 and parameters: {'alpha_actor': 0.7231211346847017, 'alpha_critic': 0.9317991764393796}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:28,950] Trial 391 finished with value: 23.77601760387634 and parameters: {'alpha_actor': 0.9364068598392817, 'alpha_critic': 0.9765262317084008}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:29,057] Trial 392 finished with value: 23.876136052043655 and parameters: {'alpha_actor': 0.6973328241648115, 'alpha_critic': 0.9307969925094628}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:29,175] Trial 393 finished with value: 23.856205653217863 and parameters: {'alpha_actor': 0.713675967087017, 'alpha_critic': 0.9567435938121946}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:29,281] Trial 394 finished with value: 23.466248157427188 and parameters: {'alpha_actor': 0.7363517885991944, 'alpha_critic': 0.13826164891812068}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:29,425] Trial 395 finished with value: 22.0016657252283 and parameters: {'alpha_actor': 0.7265068290945543, 'alpha_critic': 0.9389962090618486}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:29,561] Trial 396 finished with value: 22.120410243958368 and parameters: {'alpha_actor': 0.6799631769344888, 'alpha_critic': 0.9939588093255789}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:29,693] Trial 397 finished with value: 20.614456998076488 and parameters: {'alpha_actor': 0.9016520198250227, 'alpha_critic': 0.9185753408857952}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:29,836] Trial 398 finished with value: 22.511202944381576 and parameters: {'alpha_actor': 0.8699042071686494, 'alpha_critic': 0.6577047514298423}. Best is trial 176 with value: 25.278320955654458.
# [I 2024-10-01 22:25:29,971] Trial 399 finished with value: 21.82061474751698 and parameters: {'alpha_actor': 0.9607771361930361, 'alpha_critic': 0.6868680956862526}. Best is trial 176 with value: 25.278320955654458.
# best alpha_actor:  0.8640126169086411
# best alpha_critic:  0.912471717893264
# best value:  25.278320955654458

# %%
# Define the number of grid points to divide
num_points = 20
learning_rate_range = np.linspace(0.01, 1.0, num_points)

# Initialize the value function norm matrix
Bayes_value_norms = np.zeros((num_points, num_points))

# Iterate through the results and map alpha_actor and alpha_critic to the grid
for alpha_actor, alpha_critic, norm_v in results:
    # Find the closest indices of alpha_actor and alpha_critic in the grid
    actor_idx = np.argmin(np.abs(learning_rate_range - alpha_actor))
    critic_idx = np.argmin(np.abs(learning_rate_range - alpha_critic))
    
    # Store the norm value in the matrix
    Bayes_value_norms[actor_idx, critic_idx] = norm_v

plot_heatmap(Bayes_value_norms, "Bayes_Method")

# %% [markdown]
# # Step 3: Statistical tests
#
# Now you have to compare the performance of the actor-critic algorithm tuned
# with all the best hyper-parameters you found before, using statistical tests.
#
# The functions below are provided to run Welch's T-test over learning curves.
# They have been adapted from a github repository: https://github.com/flowersteam/rl_stats
# You don't need to understand them in detail (though it is always a good idea to try to understand more code).

# %%
from scipy.stats import ttest_ind
import bootstrapped.bootstrap as bs
import bootstrapped.compare_functions as bs_compare
import bootstrapped.stats_functions as bs_stats

# %%
def compute_central_tendency_and_error(id_central, id_error, sample):

    try:
        id_error = int(id_error)
    except:
        pass

    if id_central == "mean":
        central = np.nanmean(sample, axis=1)
    elif id_central == "median":
        central = np.nanmedian(sample, axis=1)
    else:
        raise NotImplementedError

    if isinstance(id_error, int):
        low = np.nanpercentile(sample, q=int((100 - id_error) / 2), axis=1)
        high = np.nanpercentile(sample, q=int(100 - (100 - id_error) / 2), axis=1)
    elif id_error == "std":
        low = central - np.nanstd(sample, axis=1)
        high = central + np.nanstd(sample, axis=1)
    elif id_error == "sem":
        low = central - np.nanstd(sample, axis=1) / np.sqrt(sample.shape[0])
        high = central + np.nanstd(sample, axis=1) / np.sqrt(sample.shape[0])
    else:
        raise NotImplementedError

    return central, low, high

# %%
def run_test(test_id, data1, data2, alpha=0.05):
    """
    Compute tests comparing data1 and data2 with confidence level alpha
    :param test_id: (str) refers to what test should be used
    :param data1: (np.ndarray) sample 1
    :param data2: (np.ndarray) sample 2
    :param alpha: (float) confidence level of the test
    :return: (bool) if True, the null hypothesis is rejected
    """
    data1 = data1.squeeze()
    data2 = data2.squeeze()
    n1 = data1.size
    n2 = data2.size

    # perform Welch t-test":
    _, p = ttest_ind(data1, data2, equal_var=False)
    return p < alpha

# %% [markdown]
# This last function was adapted for the lab.

# %%
def perform_test(perf1, perf2, name1, name2, sample_size=20, downsampling_fact=5, confidence_level=0.01):

    perf1 = perf1.transpose()
    perf2 = perf2.transpose()
    nb_datapoints = perf1.shape[1]
    nb_steps = perf1.shape[0]

    legend = [name1, name2]

    # what do you want to plot ?
    id_central = 'mean' # "median"  # 
    id_error = 80  # (percentiles), also: 'std', 'sem'

    test_id = "Welch t-test"  # recommended
    
    sample1 = perf1[:, np.random.randint(0, nb_datapoints, sample_size)]
    sample2 = perf2[:, np.random.randint(0, nb_datapoints, sample_size)]

    steps = np.arange(0, nb_steps, downsampling_fact)
    sample1 = sample1[steps, :]
    sample2 = sample2[steps, :]

    # test
    sign_diff = np.zeros([len(steps)])
    for i in range(len(steps)):
        sign_diff[i] = run_test(
            test_id, sample1[i, :], sample2[i, :], alpha=confidence_level
        )

    central1, low1, high1 = compute_central_tendency_and_error(
        id_central, id_error, sample1
    )
    central2, low2, high2 = compute_central_tendency_and_error(
        id_central, id_error, sample2
    )

    # plot
    _, ax = plt.subplots(1, 1, figsize=(20, 10))
    lab1 = plt.xlabel("training steps")
    lab2 = plt.ylabel("performance")

    plt.plot(steps, central1, linewidth=10)
    plt.plot(steps, central2, linewidth=10)
    plt.fill_between(steps, low1, high1, alpha=0.3)
    plt.fill_between(steps, low2, high2, alpha=0.3)
    leg = ax.legend(legend, frameon=False)

    # plot significative difference as dots
    idx = np.argwhere(sign_diff == 1)
    y = max(np.nanmax(high1), np.nanmax(high2))
    plt.scatter(steps[idx], y * 1.05 * np.ones([idx.size]), s=100, c="k", marker="o")

    # style
    for line in leg.get_lines():
        line.set_linewidth(10.0)
    ax.spines["top"].set_linewidth(5)
    ax.spines["right"].set_linewidth(5)
    ax.spines["bottom"].set_linewidth(5)
    ax.spines["left"].set_linewidth(5)

    plt.savefig(
        f"./{name1}_{name2}.png", bbox_extra_artists=(leg, lab1, lab2), bbox_inches="tight", dpi=100
    )
    # plt.show()

# %% [markdown]
# ## Exercise 3
#
# As hyper-parameters, you will use:
#
# - naive tuning, that is a pair (0.5, 0.5) for the actor and critic learning rates,
# - the best hyper-parameters you found with the different tuning algorithms you used before.
#
# ### 1. For each set of hyper-parameters, collect a large dataset of learning curves.
#
# We suggest using 150 training episodes.
#
# ### 2. Perform statistical comparisons
#
# - Take two datasets of learning curves obtained with the hyper-parameters sets that you found with different tuning algorithms.
# - Use the ``` perform_test(...)``` function to compare each possible pair of sets.
#
# You should obtain an image for each pair you have tried.
# In this image, black dots signal the time step where there is a statistically significant difference between two learning curves.
#
#  ### 3. Conclude.

# %%
# 1. For each set of hyper-parameters, collect a large dataset of learning curves
def collect_learning_curves(mdp, num_runs, nb_episodes, timeout, alpha_critic, alpha_actor, render):
    learning_curves = []

    for run in range(num_runs):
        v_list = []  # Store value norms or other performance metrics per episode

        # Run Actor-Critic algorithm
        v, v_list, _ = Actor_Critic(
            mdp, nb_episodes,
            timeout,
            alpha_critic,
            alpha_actor,
            render
        )

        # Save learning curve for this run
        learning_curves.append(v_list)

    return np.array(learning_curves)

# %%
# naive tuning
naive_alpha_critic = 0.5
naive_alpha_actor = 0.5

naive_curves = collect_learning_curves(
    mdp=env, 
    num_runs=ac_params['nb_repeats'],
    nb_episodes=150,
    timeout=ac_params['timeout'],
    alpha_actor=naive_alpha_actor, 
    alpha_critic=naive_alpha_critic,
    render=ac_params['render']
)

# %%
# Grid Search tuning
grid_search_curves = collect_learning_curves(
    mdp = env,
    num_runs=ac_params['nb_repeats'],
    nb_episodes=150,
    timeout=ac_params['timeout'],
    alpha_critic=best_critic_lr,
    alpha_actor=best_actor_lr,
    render=ac_params['render'])

# %%
# Random Search tuning
random_search_curves = collect_learning_curves(
    mdp=env,
    num_runs=ac_params['nb_repeats'],
    nb_episodes=150,
    timeout=ac_params['timeout'],
    alpha_critic=best_critic_lr_random,
    alpha_actor=best_actor_lr_random,
    render=ac_params['render']
)

# %%
# Bayesian optimization method tuning (optuna)
Bayes_alpha_critic = study.best_params["alpha_critic"]
Bayes_alpha_actor = study.best_params["alpha_actor"]

Bayes_curves = collect_learning_curves(
    mdp=env, 
    num_runs=ac_params['nb_repeats'],
    nb_episodes=150,
    timeout=ac_params['timeout'],
    alpha_actor=Bayes_alpha_actor, 
    alpha_critic=Bayes_alpha_critic,
    render=ac_params['render']
)

# %%
# 2. Perform statistical comparisons

# Naive vs Grid Search
perform_test(perf1=naive_curves, perf2=grid_search_curves, name1='Naive', name2='Grid Search')

# %%
# Naive vs Random Search
perform_test(perf1=naive_curves, perf2=random_search_curves, name1='Naive', name2='Random Search')

# %%
# Naive vs Bayes 
perform_test(perf1=naive_curves, perf2=Bayes_curves, name1='Naive', name2='Bayes')

# %%
# Grid Search vs Random Search
perform_test(perf1=grid_search_curves, perf2=random_search_curves, name1='Grid Search', name2='Random Search')

# %%
# Grid Search vs Bayes
perform_test(perf1=grid_search_curves, perf2=Bayes_curves, name1='Grid Search', name2='Bayes')

# %%
# Random Search vs Bayes
perform_test(perf1=random_search_curves, perf2=Bayes_curves, name1='Random Search', name2='Bayes')

# %% [markdown]
# # Lab report
#
# Your report should contain:
# - your source code (probably this notebook), do not forget to put your names on top of the notebook,
# - in a separate pdf file with your names in the name of the file:
#     + a detailed enough description of the choices you have made: the parameters you have set, the libraries you have used, etc.,
#     + the heatmaps obtained using the hyper-parameters tuning algorithms that you have used,
#     + the figures resulting from performing Welch's T-test using the best hyper-parameters from the above approaches,
#     + your conclusion from these experiments.
#
# Beyond the elements required in this report, any additional studies will be rewarded.
# For instance, you can try using a Q-function as critic, using random search as hyper-parameters tuning algorithm,
# using more challenging environments, etc.
