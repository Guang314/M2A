# %% [markdown]
# <center><h1>1-ab: Introduction to Neural Networks</h1></center>
#
# <center><h2><a href="https://rdfia.github.io/">Course link</a></h2></center>
#
# # Warning :
# # Do "File -> Save a copy in Drive" before you start modifying the notebook, otherwise your modifications will not be saved.

# %%
# !wget https://github.com/rdfia/rdfia.github.io/raw/master/data/2-ab.zip
# !unzip -j 2-ab.zip
# !wget https://github.com/rdfia/rdfia.github.io/raw/master/code/2-ab/utils-data.py
# Out:
# --2024-09-29 13:12:35--  https://github.com/rdfia/rdfia.github.io/raw/master/data/2-ab.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rdfia/rdfia.github.io/master/data/2-ab.zip [following]
# --2024-09-29 13:12:36--  https://raw.githubusercontent.com/rdfia/rdfia.github.io/master/data/2-ab.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13423991 (13M) [application/zip]
# Saving to: ‘2-ab.zip’
#
# 2-ab.zip            100%[===================>]  12.80M  57.9MB/s    in 0.2s
#
# 2024-09-29 13:12:36 (57.9 MB/s) - ‘2-ab.zip’ saved [13423991/13423991]
#
# Archive:  2-ab.zip
#   inflating: ._2-ab
#   inflating: circles.mat
#   inflating: ._circles.mat
#   inflating: mnist.mat
#   inflating: ._mnist.mat
#   inflating: .DS_Store
#   inflating: ._.DS_Store
# --2024-09-29 13:12:36--  https://github.com/rdfia/rdfia.github.io/raw/master/code/2-ab/utils-data.py
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rdfia/rdfia.github.io/master/code/2-ab/utils-data.py [following]
# --2024-09-29 13:12:37--  https://raw.githubusercontent.com/rdfia/rdfia.github.io/master/code/2-ab/utils-data.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3950 (3.9K) [text/plain]
# Saving to: ‘utils-data.py’
#
# utils-data.py       100%[===================>]   3.86K  --.-KB/s    in 0s
#
# 2024-09-29 13:12:37 (13.9 MB/s) - ‘utils-data.py’ saved [3950/3950]

# %%
import math
import torch
from torch.autograd import Variable
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %run 'utils-data.py'

# %% [markdown]
# # Part 1 : Forward and backward passes "by hands"

# %%
def init_params(nx, nh, ny):
    """
    nx, nh, ny: integers
    out params: dictionnary
    """
    params = {}

    #####################
    ## Your code here  ##
    #####################
    # fill values for Wh, Wy, bh, by

    params["Wh"] = torch.randn(size=(nh,nx))
    params["Wy"] = torch.randn(size=(ny,nh))
    params["bh"] = torch.zeros(size=(1,nh))
    params["by"] = torch.zeros(size=(1,ny))

    ####################
    ##      END        #
    ####################
    return params

# %%
def forward(params, X):
    """
    params: dictionnary
    X: (n_batch, dimension)
    """
    bsize = X.size(0)
    nh = params['Wh'].size(0)
    ny = params['Wy'].size(0)
    outputs = {}

    #####################
    ## Your code here  ##
    #####################
    # fill values for X, htilde, h, ytilde, yhat

    outputs["X"] = X
    outputs["htilde"] = torch.mm(X, params["Wh"].T) + params["bh"]
    outputs["h"] = torch.tanh(outputs["htilde"])
    outputs["ytilde"] = torch.mm(outputs["h"], params["Wy"].T) + params["by"]
    outputs["yhat"] = torch.exp(outputs["ytilde"]) / torch.sum(torch.exp(outputs["ytilde"]), dim=1, keepdim=True)

    ####################
    ##      END        #
    ####################

    return outputs['yhat'], outputs

# %%
def loss_accuracy(Yhat, Y):

    #####################
    ## Your code here  ##
    #####################

    L = (-1) * torch.mean(torch.sum(Y * torch.log(Yhat), dim=1), dim=0)

    _,indsYhat = torch.max(Yhat,1)
    _,indsY = torch.max(Y,1)
    correct = (indsYhat == indsY).sum()
    acc = correct / Y.size(0)

    ####################
    ##      END        #
    ####################

    return L, acc

# %%
def backward(params, outputs, Y):
    bsize = Y.shape[0]
    grads = {}

    #####################
    ## Your code here  ##
    #####################
    # fill values for Wy, Wh, by, bh

    delta_y = outputs["yhat"] - Y
    delta_h = torch.mm(delta_y,params["Wy"]) * (1 - outputs["h"]**2)
    grads["Wy"] = torch.mm(delta_y.T, outputs["h"])
    grads["Wh"] = torch.mm(delta_h.T, outputs["X"])
    grads["by"] = torch.sum(delta_y, dim=0)
    grads["bh"] = torch.sum(delta_h, dim=0)

    ####################
    ##      END        #
    ####################
    return grads

# %%
def sgd(params, grads, eta):

    #####################
    ## Your code here  ##
    #####################
    # update the params values

    params["Wh"] = params["Wh"] - eta * grads["Wh"]
    params["Wy"] = params["Wy"] - eta * grads["Wy"]
    params["bh"] = params["bh"] - eta * grads["bh"]
    params["by"] = params["by"] - eta * grads["by"]

    ####################
    ##      END        #
    ####################
    return params

# %% [markdown]
# ## Global learning procedure "by hands"

# %%
# init
data = CirclesData()
data.plot_data()
N = data.Xtrain.shape[0]
Nbatch = 10
nx = data.Xtrain.shape[1]
nh = 10
ny = data.Ytrain.shape[1]
eta = 0.03

params = init_params(nx, nh, ny)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code here  ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]

        # write the optimization algorithm on the batch (X,Y)
        # using the functions: forward, loss_accuracy, backward, sgd
        Yhat, ouputs = forward(params, X)
        Loss, acc = loss_accuracy(Yhat, Y)
        grads = backward(params, ouputs, Y)
        params = sgd(params, grads, eta)


    ####################
    ##      END        #
    ####################


    Yhat_train, _ = forward(params, data.Xtrain)
    Yhat_test, _ = forward(params, data.Xtest)
    Ltrain, acctrain = loss_accuracy(Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(Yhat_test, data.Ytest)
    Ygrid, _ = forward(params, data.Xgrid)

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title)
    data.plot_data_with_grid(Ygrid, title)

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain)
    curves[3].append(Ltest)

fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
plt.plot(curves[2], label="loss train")
plt.plot(curves[3], label="loss test")
plt.legend()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Part 2 : Simplification of the backward pass with `torch.autograd`

# %%
def init_params(nx, nh, ny):
    """
    nx, nh, ny: integers
    out params: dictionnary
    """
    params = {}

    #####################
    ## Your code here  ##
    #####################
    # fill values for Wh, Wy, bh, by
    # activaye autograd on the network weights

    params["Wh"] = torch.randn(nh, nx, requires_grad=True)
    params["Wy"] = torch.randn(ny, nh, requires_grad=True)
    params["bh"] = torch.zeros(1, nh, requires_grad=True)
    params["by"] = torch.zeros(1, ny, requires_grad=True)

    ####################
    ##      END        #
    ####################
    return params

# %% [markdown]
# The function `forward` remains unchanged from previous part.
#
# The function `backward` is no longer used because of "autograd".

# %%
def sgd(params, eta):

    #####################
    ## Your code here  ##
    #####################
    # update the network weights
    # warning: use torch.no_grad()
    with torch.no_grad():
        params["Wh"] -= eta * params["Wh"].grad
        params["Wy"] -= eta * params['Wy'].grad
        params["bh"] -= eta * params["bh"].grad
        params["by"] -= eta * params["by"].grad

    # and reset to zero the gradient accumulators

        params["Wh"].grad.zero_()
        params["Wy"].grad.zero_()
        params["bh"].grad.zero_()
        params["by"].grad.zero_()

    ####################
    ##      END        #
    ####################
    return params

# %% [markdown]
# ## Global learning procedure with autograd

# %%
# init
data = CirclesData()
data.plot_data()
N = data.Xtrain.shape[0]
Nbatch = 10
nx = data.Xtrain.shape[1]
nh = 10
ny = data.Ytrain.shape[1]
eta = 0.03

params = init_params(nx, nh, ny)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code here  ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]

        # write the optimization algorithm on the batch (X,Y)
        # using the functions: forward, loss_accuracy, sgd
        # and the backward function with autograd

        Yhat, ouputs = forward(params, X)
        Loss, acc = loss_accuracy(Yhat, Y)
        Loss.backward()
        params = sgd(params, eta)

    ####################
    ##      END        #
    ####################


    Yhat_train, _ = forward(params, data.Xtrain)
    Yhat_test, _ = forward(params, data.Xtest)
    Ltrain, acctrain = loss_accuracy(Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(Yhat_test, data.Ytest)
    Ygrid, _ = forward(params, data.Xgrid)

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title)
    # detach() is used to remove the predictions from the computational graph in autograd
    data.plot_data_with_grid(Ygrid.detach(), title)

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain)
    curves[3].append(Ltest)

fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
# plt.plot(curves[2], label="loss train")
plt.plot([x.detach().numpy() for x in curves[2]], label="loss train")
# plt.plot(curves[3], label="loss test")
plt.plot([x.detach().numpy() for x in curves[3]], label="loss test")
plt.legend()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Part 3 : Simplification of the forward pass with `torch.nn`

# %% [markdown]
# `init_params` and `forward` are replaced by the `init_model` function which defines the network architecture and the loss.

# %%
def init_model(nx, nh, ny):

    #####################
    ## Your code here  ##
    #####################

    model = torch.nn.Sequential(
        torch.nn.Linear(nx,nh),
        torch.nn.Tanh(),
        torch.nn.Linear(nh,ny),
    )
    loss = torch.nn.CrossEntropyLoss()

    ####################
    ##      END        #
    ####################

    return model, loss

# %%
def loss_accuracy(loss, Yhat, Y):

    #####################
    ## Your code here  ##
    #####################
    # call the loss function

    L = loss(Yhat,Y)

    _,indsYhat = torch.max(Yhat,1)
    _,indsY = torch.max(Y,1)
    correct = (indsYhat == indsY).sum()
    acc = correct / Y.size(0)

    ####################
    ##      END        #
    ####################

    return L, acc

# %%
def sgd(model, eta):

    #####################
    ## Your code here  ##
    #####################
    # update the network weights
    # warning: use torch.no_grad()
    # and reset to zero the gradient accumulators

    with torch.no_grad():
      for param in model.parameters():
        param -= eta * param.grad
      model.zero_grad()

    ####################
    ##      END        #
    ####################
    return model

# %% [markdown]
# ## Global learning procedure with autograd and `torch.nn`

# %%
# init
data = CirclesData()
data.plot_data()
N = data.Xtrain.shape[0]
Nbatch = 10
nx = data.Xtrain.shape[1]
nh = 10
ny = data.Ytrain.shape[1]
eta = 0.03

model, loss = init_model(nx, nh, ny)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code here  ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]

        # write the optimization algorithm on the batch (X,Y)
        # using the functions: loss_accuracy, sgd
        # the forward with the predict method from the model
        # and the backward function with autograd

        Yhat = model(X)
        L, acc = loss_accuracy(loss, Yhat, Y)
        L.backward()
        model = sgd(model, eta)

    ####################
    ##      END        #
    ####################


    Yhat_train = model(data.Xtrain)
    Yhat_test = model(data.Xtest)
    Ltrain, acctrain = loss_accuracy(loss, Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(loss, Yhat_test, data.Ytest)
    Ygrid = model(data.Xgrid)

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title)
    data.plot_data_with_grid(torch.nn.Softmax(dim=1)(Ygrid.detach()), title)

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain)
    curves[3].append(Ltest)

fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
# plt.plot(curves[2], label="loss train")
plt.plot([x.detach().numpy() for x in curves[2]], label="loss train")
# plt.plot(curves[3], label="loss test")
plt.plot([x.detach().numpy() for x in curves[3]], label="loss test")
plt.legend()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Part 4 : Simplification of the SGD with `torch.optim`

# %%
def init_model(nx, nh, ny, eta):

    #####################
    ## Your code here  ##
    #####################

    model = torch.nn.Sequential(
        torch.nn.Linear(nx,nh),
        torch.nn.Tanh(),
        torch.nn.Linear(nh,ny),
    )

    loss = torch.nn.CrossEntropyLoss()

    optim = torch.optim.SGD(model.parameters(), lr=eta)

    ####################
    ##      END        #
    ####################

    return model, loss, optim

# %% [markdown]
# The `sgd` function is replaced by calling the `optim.zero_grad()` before the backward and `optim.step()` after.

# %% [markdown]
# ## Algorithme global d'apprentissage (avec autograd, les couches `torch.nn` et `torch.optim`)

# %%
# init
data = CirclesData()
data.plot_data()
N = data.Xtrain.shape[0]
Nbatch = 10
nx = data.Xtrain.shape[1]
nh = 10
ny = data.Ytrain.shape[1]
eta = 0.03

model, loss, optim = init_model(nx, nh, ny, eta)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code  here ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]

        # write the optimization algorithm on the batch (X,Y)
        # using the functions: loss_accuracy
        # the forward with the predict method from the model
        # the backward function with autograd
        # and then an optimization step

        Yhat = model(X)
        L, acc = loss_accuracy(loss,Yhat,Y)
        optim.zero_grad()
        L.backward()
        optim.step()

    ####################
    ##      FIN        #
    ####################


    Yhat_train = model(data.Xtrain)
    Yhat_test = model(data.Xtest)
    Ltrain, acctrain = loss_accuracy(loss, Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(loss, Yhat_test, data.Ytest)
    Ygrid = model(data.Xgrid)

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title)
    data.plot_data_with_grid(torch.nn.Softmax(dim=1)(Ygrid.detach()), title)

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain)
    curves[3].append(Ltest)

fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
# plt.plot(curves[2], label="loss train")
plt.plot([x.detach().numpy() for x in curves[2]], label="loss train")
# plt.plot(curves[3], label="loss test")
plt.plot([x.detach().numpy() for x in curves[3]], label="loss test")
plt.legend()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Part 5 : MNIST

# %% [markdown]
# Apply the code from previous part code to the MNIST dataset.

# %%
# init
data = MNISTData()
N = data.Xtrain.shape[0]
Nbatch = 100
nx = data.Xtrain.shape[1]
nh = 100
ny = data.Ytrain.shape[1]
eta = 0.03

model, loss, optim = init_model(nx, nh, ny, eta)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code  here ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]

        # write the optimization algorithm on the batch (X,Y)
        # using the functions: loss_accuracy
        # the forward with the predict method from the model
        # the backward function with autograd
        # and then an optimization step

        Yhat = model(X)
        L, acc = loss_accuracy(loss,Yhat,Y)
        optim.zero_grad()
        L.backward()
        optim.step()

    ####################
    ##      FIN        #
    ####################


    Yhat_train = model(data.Xtrain)
    Yhat_test = model(data.Xtest)
    Ltrain, acctrain = loss_accuracy(loss, Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(loss, Yhat_test, data.Ytest)
    # Ygrid = model(data.Xgrid)

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title)
    # data.plot_data_with_grid(torch.nn.Softmax(dim=1)(Ygrid.detach()), title)

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain)
    curves[3].append(Ltest)

fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
# plt.plot(curves[2], label="loss train")
plt.plot([x.detach().numpy() for x in curves[2]], label="loss train")
# plt.plot(curves[3], label="loss test")
plt.plot([x.detach().numpy() for x in curves[3]], label="loss test")
plt.legend()
plt.show()
# Out:
# Iter 0: Acc train 0.9% (0.50), acc test 0.9% (0.48)
# Iter 1: Acc train 0.9% (0.49), acc test 0.9% (0.48)
# Iter 2: Acc train 0.9% (0.42), acc test 0.9% (0.41)
# Iter 3: Acc train 0.9% (0.40), acc test 0.9% (0.40)
# Iter 4: Acc train 0.9% (0.43), acc test 0.9% (0.42)
# Iter 5: Acc train 0.9% (0.40), acc test 0.9% (0.40)
# Iter 6: Acc train 0.9% (0.42), acc test 0.9% (0.42)
# Iter 7: Acc train 0.9% (0.39), acc test 0.9% (0.38)
# Iter 8: Acc train 0.9% (0.39), acc test 0.9% (0.39)
# Iter 9: Acc train 0.9% (0.41), acc test 0.9% (0.40)
# Iter 10: Acc train 0.9% (0.39), acc test 0.9% (0.39)
# Iter 11: Acc train 0.9% (0.39), acc test 0.9% (0.39)
# Iter 12: Acc train 0.9% (0.39), acc test 0.9% (0.39)
# Iter 13: Acc train 0.9% (0.38), acc test 0.9% (0.38)
# Iter 14: Acc train 0.9% (0.35), acc test 0.9% (0.34)
# Iter 15: Acc train 0.9% (0.35), acc test 0.9% (0.35)
# Iter 16: Acc train 0.9% (0.38), acc test 0.9% (0.38)
# Iter 17: Acc train 0.9% (0.36), acc test 0.9% (0.35)
# Iter 18: Acc train 0.9% (0.38), acc test 0.9% (0.38)
# Iter 19: Acc train 0.9% (0.36), acc test 0.9% (0.36)
# Iter 20: Acc train 0.9% (0.38), acc test 0.9% (0.38)
# Iter 21: Acc train 0.9% (0.35), acc test 0.9% (0.34)
# Iter 22: Acc train 0.9% (0.36), acc test 0.9% (0.35)
# Iter 23: Acc train 0.9% (0.33), acc test 0.9% (0.32)
# Iter 24: Acc train 0.9% (0.35), acc test 0.9% (0.35)
# Iter 25: Acc train 0.9% (0.33), acc test 0.9% (0.33)
# Iter 26: Acc train 0.9% (0.34), acc test 0.9% (0.33)
# Iter 27: Acc train 0.9% (0.33), acc test 0.9% (0.32)
# Iter 28: Acc train 0.9% (0.34), acc test 0.9% (0.34)
# Iter 29: Acc train 0.9% (0.34), acc test 0.9% (0.33)
# Iter 30: Acc train 0.9% (0.32), acc test 0.9% (0.32)
# Iter 31: Acc train 0.9% (0.32), acc test 0.9% (0.32)
# Iter 32: Acc train 0.9% (0.33), acc test 0.9% (0.33)
# Iter 33: Acc train 0.9% (0.33), acc test 0.9% (0.34)
# Iter 34: Acc train 0.9% (0.30), acc test 0.9% (0.30)
# Iter 35: Acc train 0.9% (0.32), acc test 0.9% (0.33)
# Iter 36: Acc train 0.9% (0.30), acc test 0.9% (0.30)
# Iter 37: Acc train 0.9% (0.29), acc test 0.9% (0.29)
# Iter 38: Acc train 0.9% (0.30), acc test 0.9% (0.30)
# Iter 39: Acc train 0.9% (0.30), acc test 0.9% (0.29)
# Iter 40: Acc train 0.9% (0.31), acc test 0.9% (0.31)
# Iter 41: Acc train 0.9% (0.29), acc test 0.9% (0.28)
# Iter 42: Acc train 0.9% (0.28), acc test 0.9% (0.28)
# Iter 43: Acc train 0.9% (0.27), acc test 0.9% (0.28)
# Iter 44: Acc train 0.9% (0.27), acc test 0.9% (0.27)
# Iter 45: Acc train 0.9% (0.30), acc test 0.9% (0.31)
# Iter 46: Acc train 0.9% (0.28), acc test 0.9% (0.28)
# Iter 47: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 48: Acc train 0.9% (0.27), acc test 0.9% (0.27)
# Iter 49: Acc train 0.9% (0.25), acc test 0.9% (0.24)
# Iter 50: Acc train 0.9% (0.26), acc test 0.9% (0.27)
# Iter 51: Acc train 0.9% (0.27), acc test 0.9% (0.26)
# Iter 52: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 53: Acc train 0.9% (0.27), acc test 0.9% (0.28)
# Iter 54: Acc train 0.9% (0.27), acc test 0.9% (0.27)
# Iter 55: Acc train 0.9% (0.26), acc test 0.9% (0.25)
# Iter 56: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 57: Acc train 0.9% (0.27), acc test 0.9% (0.27)
# Iter 58: Acc train 0.9% (0.25), acc test 0.9% (0.24)
# Iter 59: Acc train 0.9% (0.27), acc test 0.9% (0.27)
# Iter 60: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 61: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 62: Acc train 0.9% (0.25), acc test 0.9% (0.24)
# Iter 63: Acc train 0.9% (0.26), acc test 0.9% (0.25)
# Iter 64: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 65: Acc train 0.9% (0.27), acc test 0.9% (0.26)
# Iter 66: Acc train 0.9% (0.29), acc test 0.9% (0.29)
# Iter 67: Acc train 0.9% (0.28), acc test 0.9% (0.28)
# Iter 68: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 69: Acc train 0.9% (0.28), acc test 0.9% (0.28)
# Iter 70: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 71: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 72: Acc train 0.9% (0.24), acc test 0.9% (0.24)
# Iter 73: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 74: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 75: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 76: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 77: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 78: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 79: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 80: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 81: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 82: Acc train 0.9% (0.24), acc test 0.9% (0.25)
# Iter 83: Acc train 0.9% (0.24), acc test 0.9% (0.24)
# Iter 84: Acc train 0.9% (0.24), acc test 0.9% (0.24)
# Iter 85: Acc train 0.9% (0.24), acc test 0.9% (0.25)
# Iter 86: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 87: Acc train 0.9% (0.27), acc test 0.9% (0.26)
# Iter 88: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 89: Acc train 0.9% (0.27), acc test 0.9% (0.26)
# Iter 90: Acc train 0.9% (0.27), acc test 0.9% (0.27)
# Iter 91: Acc train 0.9% (0.26), acc test 0.9% (0.25)
# Iter 92: Acc train 0.9% (0.26), acc test 0.9% (0.27)
# Iter 93: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 94: Acc train 0.9% (0.24), acc test 0.9% (0.25)
# Iter 95: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 96: Acc train 0.9% (0.26), acc test 0.9% (0.25)
# Iter 97: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 98: Acc train 0.9% (0.26), acc test 0.9% (0.27)
# Iter 99: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 100: Acc train 0.9% (0.24), acc test 0.9% (0.23)
# Iter 101: Acc train 0.9% (0.23), acc test 0.9% (0.22)
# Iter 102: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 103: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 104: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 105: Acc train 0.9% (0.24), acc test 0.9% (0.26)
# Iter 106: Acc train 0.9% (0.24), acc test 0.9% (0.26)
# Iter 107: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 108: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 109: Acc train 0.9% (0.24), acc test 0.9% (0.25)
# Iter 110: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 111: Acc train 0.9% (0.24), acc test 0.9% (0.24)
# Iter 112: Acc train 0.9% (0.26), acc test 0.9% (0.26)
# Iter 113: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 114: Acc train 0.9% (0.25), acc test 0.9% (0.25)
# Iter 115: Acc train 0.9% (0.24), acc test 0.9% (0.24)
# Iter 116: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 117: Acc train 0.9% (0.24), acc test 0.9% (0.24)
# Iter 118: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 119: Acc train 0.9% (0.21), acc test 0.9% (0.21)
# Iter 120: Acc train 0.9% (0.21), acc test 0.9% (0.21)
# Iter 121: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 122: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 123: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 124: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 125: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 126: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 127: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 128: Acc train 0.9% (0.22), acc test 0.9% (0.21)
# Iter 129: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 130: Acc train 0.9% (0.22), acc test 0.9% (0.22)
# Iter 131: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 132: Acc train 0.9% (0.22), acc test 0.9% (0.22)
# Iter 133: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 134: Acc train 0.9% (0.22), acc test 0.9% (0.22)
# Iter 135: Acc train 0.9% (0.22), acc test 0.9% (0.22)
# Iter 136: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 137: Acc train 0.9% (0.22), acc test 0.9% (0.22)
# Iter 138: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 139: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 140: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 141: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 142: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 143: Acc train 0.9% (0.24), acc test 0.9% (0.24)
# Iter 144: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 145: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 146: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 147: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 148: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 149: Acc train 0.9% (0.22), acc test 0.9% (0.23)

# %% [markdown]
# # Part 6: Bonus: SVM
#
#
# Train a SVM model on the Circles dataset.
#
# Ideas :
# - First try a linear SVM (sklearn.svm.LinearSVC dans scikit-learn). Does it work well ? Why ?
# - Then try more complex kernels (sklearn.svm.SVC). Which one is the best ? why ?
# - Does the parameter C of regularization have an impact? Why ?

# %%
# data
data = CirclesData()
Xtrain = data.Xtrain.numpy()
Ytrain = data.Ytrain[:, 0].numpy()

Xgrid = data.Xgrid.numpy()

Xtest = data.Xtest.numpy()
Ytest = data.Ytest[:, 0].numpy()

def plot_svm_predictions(data, predictions):
      plt.figure(2)
      plt.clf()
      plt.imshow(np.reshape(predictions, (40,40)))
      plt.plot(data._Xtrain[data._Ytrain[:,0] == 1,0]*10+20, data._Xtrain[data._Ytrain[:,0] == 1,1]*10+20, 'bo', label="Train")
      plt.plot(data._Xtrain[data._Ytrain[:,1] == 1,0]*10+20, data._Xtrain[data._Ytrain[:,1] == 1,1]*10+20, 'ro')
      plt.plot(data._Xtest[data._Ytest[:,0] == 1,0]*10+20, data._Xtest[data._Ytest[:,0] == 1,1]*10+20, 'b+', label="Test")
      plt.plot(data._Xtest[data._Ytest[:,1] == 1,0]*10+20, data._Xtest[data._Ytest[:,1] == 1,1]*10+20, 'r+')
      plt.xlim(0,39)
      plt.ylim(0,39)
      plt.clim(0.3,0.7)
      plt.draw()
      plt.pause(1e-3)

# %%
import sklearn.svm
from sklearn.svm import LinearSVC

############################
### Your code here   #######
### Train the SVM    #######
## See https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html
## and https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
############################

svm = LinearSVC(C=0.5)
svm.fit(Xtrain,Ytrain)

###########################
# Out:
# LinearSVC(C=0.5)

# %%
## Print results

Ytest_pred = svm.predict(Xtest)
accuracy = np.sum(Ytest == Ytest_pred) / len(Ytest)
print(f"Accuracy : {100 * accuracy:.2f}")
Ygrid_pred = svm.predict(Xgrid)
plot_svm_predictions(data, Ygrid_pred)
# Out:
# Accuracy : 53.00

# %%
from sklearn.svm import SVC

rbf_svm = SVC(C=0.5,kernel='rbf')
rbf_svm.fit(Xtrain,Ytrain)

## Print results

Ytest_pred_rbf = rbf_svm.predict(Xtest)
accuracy = np.sum(Ytest == Ytest_pred_rbf) / len(Ytest)
print(f"Accuracy : {100 * accuracy:.2f}")
Ygrid_pred_rbf = rbf_svm.predict(Xgrid)
plot_svm_predictions(data, Ygrid_pred_rbf)
# Out:
# Accuracy : 95.50

# %%
poly_svm = SVC(kernel='poly', degree=3)
poly_svm.fit(Xtrain, Ytrain)

## Print results

Ytest_pred_poly = poly_svm.predict(Xtest)
accuracy = np.sum(Ytest == Ytest_pred_poly) / len(Ytest)
print(f"Accuracy : {100 * accuracy:.2f}")
Ygrid_pred_poly = poly_svm.predict(Xgrid)
plot_svm_predictions(data, Ygrid_pred_poly)
# Out:
# Accuracy : 54.50

# %%
sigmoid_svm = SVC(kernel='sigmoid')
sigmoid_svm.fit(Xtrain, Ytrain)

## Print results

Ytest_pred_sigmoid = sigmoid_svm.predict(Xtest)
accuracy = np.sum(Ytest == Ytest_pred_sigmoid) / len(Ytest)
print(f"Accuracy : {100 * accuracy:.2f}")
Ygrid_pred_sigmoid = sigmoid_svm.predict(Xgrid)
plot_svm_predictions(data, Ygrid_pred_sigmoid)
# Out:
# Accuracy : 65.00
